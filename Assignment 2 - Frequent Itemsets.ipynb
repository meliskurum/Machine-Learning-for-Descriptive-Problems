# %% [markdown]
# ## Task 2: Finding Similar Items
#
# Using the anthologies abstract dataset. Extract a list of the authors and editors per publication and create baskets and perform a search of similar items:
#
# basket 1: Mostafazadeh Davani Aida,Kiela Douwe,Lambert Mathias,Vidgen, Bertie Prabhakaran Vinodkumar, Waseem, Zeerak<br>
# basket 2: Singh Sumer, Li Sheng
#
# 1. Find the frequent pair of items (2-tuples) using the naïve, A-priori and PCY algorithms. For each of these compare the time of execution and results for supports s=10, 50, 100. Comment your results.
#
# 2. For the PCY algorithm, create up to 5 compact hash tables. What is  the difference in results and time of execution for 1,2,3,4 and 5 tables? Comment your results.
#
# 3. Find the final list of k-frequent items (k-tuples) for k=3 and 4. Experiment a bit and describe the best value for the support in each case. *Warning*: You can use any of the three algorithms, but be careful, because the algorithm can take too long if you don't chose it properly (well, basically don't use the naïve approach ;)).
#
# 4. Using one of the results of the previous items, for one k (k=2 or 3) find the possible clusters using the 1-NN criteria. Comment your results.
#
# > 1-NN means that if you have a tuple {A,B,C} and {C,E,F} then because they share one element {C}, then they belong to the same cluster  {A,B,C,E,F}.

# %% [markdown]
# ### Extracting a list of the authors and editors per publication and creating baskets

# %%
# import text
import pandas as pd
from urllib.request import urlopen
from io import BytesIO
import gzip

url = 'https://aclanthology.org/anthology+abstracts.bib.gz'
with gzip.open(BytesIO(urlopen(url).read()), 'rb') as fb:
    with open('test.bib', 'wb') as f:
        f.write(fb.read())
        
file = open('test.bib')
for n in range(20):
    print(file.readline()[:-1])
# Out:
# @proceedings{woah-2021-online,
#     title = "Proceedings of the 5th Workshop on Online Abuse and Harms (WOAH 2021)",
#     editor = "Mostafazadeh Davani, Aida  and
#       Kiela, Douwe  and
#       Lambert, Mathias  and
#       Vidgen, Bertie  and
#       Prabhakaran, Vinodkumar  and
#       Waseem, Zeerak",
#     month = aug,
#     year = "2021",
#     address = "Online",
#     publisher = "Association for Computational Linguistics",
#     url = "https://aclanthology.org/2021.woah-1.0",
# }
# @inproceedings{singh-li-2021-exploiting,
#     title = "Exploiting Auxiliary Data for Offensive Language Detection with Bidirectional Transformers",
#     author = "Singh, Sumer  and
#       Li, Sheng",
#     booktitle = "Proceedings of the 5th Workshop on Online Abuse and Harms (WOAH 2021)",
#     month = aug,

# %%
# putting authors into a list
authors = []
copy = False

with open('anthology+abstracts.bib', encoding="utf8") as bibtex_file:
    for line in bibtex_file:
        if line.startswith( '    author = "' ):
            copy = True
        if line.startswith( '    booktitle = "' ):
            copy = False
        if copy:
            authors.append(line)

# %%
# showing the last 10 rows of authors
authors[:10]
# Out:
# ['    author = "Singh, Sumer  and\n',
#  '      Li, Sheng",\n',
#  '    author = "Hahn, Vanessa  and\n',
#  '      Ruiter, Dana  and\n',
#  '      Kleinbauer, Thomas  and\n',
#  '      Klakow, Dietrich",\n',
#  '    author = "Caselli, Tommaso  and\n',
#  '      Basile, Valerio  and\n',
#  "      Mitrovi{\\'c}, Jelena  and\n",
#  '      Granitzer, Michael",\n']

# %%
# Cleaning the list
authors = [x.replace('    author = ', '') for x in authors]
authors = [x.replace('      ', '') for x in authors]
authors = [x.replace('  and\n', '') for x in authors]
authors = [x.replace(', ', ' ') for x in authors]
authors = [x.replace('"', '') for x in authors]
authors = [x.replace(',', '') for x in authors]

# %%
import re

authors_new = []
for s in authors:
    authors_new.extend(re.split(r'(?=\n)', s))

# %%
authors_new = [x.replace('\n', '') for x in authors_new]
authors_new[:10]
# Out:
# ['Singh Sumer',
#  'Li Sheng',
#  '',
#  'Hahn Vanessa',
#  'Ruiter Dana',
#  'Kleinbauer Thomas',
#  'Klakow Dietrich',
#  '',
#  'Caselli Tommaso',
#  'Basile Valerio']

# %%
# putting editors into a list
editors = []
copy = False

with open('anthology+abstracts.bib', encoding="utf8") as bibtex_file:
    for line in bibtex_file:
        if line.startswith( '    editor = "' ):
            copy = True
        if line.startswith( '    month = ' ):
            copy = False
        if copy:
            editors.append(line)

# %%
# showing the last 10 rows of editors list
editors[:10]
# Out:
# ['    editor = "Mostafazadeh Davani, Aida  and\n',
#  '      Kiela, Douwe  and\n',
#  '      Lambert, Mathias  and\n',
#  '      Vidgen, Bertie  and\n',
#  '      Prabhakaran, Vinodkumar  and\n',
#  '      Waseem, Zeerak",\n',
#  '    editor = "Xu, Wei  and\n',
#  '      Ritter, Alan  and\n',
#  '      Baldwin, Tim  and\n',
#  '      Rahimi, Afshin",\n']

# %%
# Cleaning the list
editors = [x.replace('    editor = ', '') for x in editors]
editors = [x.replace('      ', '') for x in editors]
editors = [x.replace('  and\n', '') for x in editors]
editors = [x.replace(', ', ' ') for x in editors]
editors = [x.replace('"', '') for x in editors]
editors = [x.replace(',', '') for x in editors]

# %%
import re

editors_new = []
for s in editors:
    editors_new.extend(re.split(r'(?=\n)', s))

# %%
editors_new = [x.replace('\n', '') for x in editors_new]
editors_new[:10]
# Out:
# ['Mostafazadeh Davani Aida',
#  'Kiela Douwe',
#  'Lambert Mathias',
#  'Vidgen Bertie',
#  'Prabhakaran Vinodkumar',
#  'Waseem Zeerak',
#  '',
#  'Xu Wei',
#  'Ritter Alan',
#  'Baldwin Tim']

# %%
#uniting authors and editors lists
all_authors = authors_new + editors_new
all_authors[:10]
# Out:
# ['Singh Sumer',
#  'Li Sheng',
#  '',
#  'Hahn Vanessa',
#  'Ruiter Dana',
#  'Kleinbauer Thomas',
#  'Klakow Dietrich',
#  '',
#  'Caselli Tommaso',
#  'Basile Valerio']

# %%
# the number of authors
len(all_authors)
# Out:
# 349876

# %%
# saving all the authors and editors as a txt file
output_file = open('all_authors.txt', 'w', encoding = 'utf-8')

for author in all_authors:
    output_file.write(author + '\n')

output_file.close()

# %%
def readdata(k, fname="all_authors.txt", report=False):
    C_k = []
    b = 0

    with open(fname, "rt", encoding='latin1') as f:
        for line in f:
            line = line.replace('\n', '')  # remove newline symbol
            if report:
                print(line)
         
            if line != "":
                # gather all items in one basket
                C_k.append(line)
            else:
                # end of basket, report all itemsets
                for itemset in itertools.combinations(C_k, k):
                    yield frozenset(itemset)
                C_k = []
                
                if report:
                    print("")

                # report progress
                # print every 1000th element to reduce clutter
                if report:
                    if b % 1000 == 0:
                        print('processing bin ', b)
                    b += 1

    # last basket
    if len(C_k) > 0:
        for itemset in itertools.combinations(C_k, k):
            yield frozenset(itemset)

# %%
readdata(k = 1)
# Out:
# <generator object readdata at 0x000001FA9F7E09E0>

# %%
import itertools
nitems = 5
for C_k in readdata(k = 1,report=True):
    print(C_k)
    nitems -= 1
    
    if nitems == 0:
        break
# Out:
# Singh Sumer
# Li Sheng
#
# frozenset({'Singh Sumer'})
# frozenset({'Li Sheng'})
#
# processing bin  0
# Hahn Vanessa
# Ruiter Dana
# Kleinbauer Thomas
# Klakow Dietrich
#
# frozenset({'Hahn Vanessa'})
# frozenset({'Ruiter Dana'})
# frozenset({'Kleinbauer Thomas'})

# %% [markdown]
# ## 1. Find the frequent pair of items (2-tuples) using the naïve, A-priori and PCY algorithms. For each of these compare the time of execution and results for supports s=10, 50, 100. Comment your results.

# %% [markdown]
# For many frequent-itemset algorithms, main-memory is the critical resource.
#
# Naive Approach read file once, counting in main memory the occurrences of each pair. The problem with the Naive method is that when we have too many items pairs they do not fit into memory.
#
# A-priori limits the need for main memory.
#
# PCY algorithm is a slightly modified version of the A-priori algorithm. It only stores the individual item counts.

# %% [markdown]
# ## Naive Approach

# %%
import time

def get_C(k):

    start = time.time()
    C = {}
    for key in readdata(k):  # False report
        if key not in C:
            C[key] = 1
        else:
            C[key] += 1
    print("Took {}s for k={}".format((time.time() - start), k))
    return C


C1 = get_C(1)
C2 = get_C(2)
# Out:
# Took 0.4076042175292969s for k=1
# Took 0.7630152702331543s for k=2

# %%
print(len(C1),len(C2))
# Out:
# 74315 248623

# %%
nitems = 10
for ck,n in C2.items():
    print(ck, n)
    nitems -= 1
    if nitems == 0: break
# Out:
# frozenset({'Singh Sumer', 'Li Sheng'}) 1
# frozenset({'Ruiter Dana', 'Hahn Vanessa'}) 1
# frozenset({'Hahn Vanessa', 'Kleinbauer Thomas'}) 1
# frozenset({'Klakow Dietrich', 'Hahn Vanessa'}) 1
# frozenset({'Ruiter Dana', 'Kleinbauer Thomas'}) 1
# frozenset({'Ruiter Dana', 'Klakow Dietrich'}) 5
# frozenset({'Klakow Dietrich', 'Kleinbauer Thomas'}) 2
# frozenset({'Basile Valerio', 'Caselli Tommaso'}) 3
# frozenset({"Mitrovi{\\'c} Jelena", 'Caselli Tommaso'}) 3
# frozenset({'Granitzer Michael', 'Caselli Tommaso'}) 3

# %% [markdown]
# ### Naive Approach, s = 10

# %%
start = time.time()
s = 10 # support threshold
L2 = {}
for key, n in C2.items():
    if n >= s:
        L2[key] = n
print('Naive Approach: {} items with >{} occurances'.format(len(L2), s))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# Naive Approach: 1713 items with >10 occurances
# It took 0.04 sec.

# %% [markdown]
# ### Naive Approach, s = 50

# %%
start = time.time()
s = 50 # support threshold
L2 = {}
for key, n in C2.items():
    if n >= s:
        L2[key] = n
print('Naive approach: {} items with >{} occurances'.format(len(L2), s))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# Naive approach: 12 items with >50 occurances
# It took 0.04 sec.

# %% [markdown]
# ### Naive Approach, s = 100

# %%
start = time.time()
s = 100 # support threshold
L2 = {}
for key, n in C2.items():
    if n >= s:
        L2[key] = n
print('Naive approach: {} items with >{} occurances'.format(len(L2), s))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# Naive approach: 0 items with >100 occurances
# It took 0.03 sec.

# %% [markdown]
# As we increase the support threshold the number of frequent items decreases.

# %% [markdown]
# ## A-priori

# %% [markdown]
# ### A-priori, s = 10

# %%
start = time.time()

N = 10  # frequency threshold

# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('A-priori: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 37555 items
# A-priori: 1713 items with >10 occurances
# It took 35.75 sec.

# %% [markdown]
# ### A-priori, s = 50

# %%
start = time.time()
N = 50  # frequency threshold

# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('A-priori: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 521 items with >50 occurances
# 3516 items
# A-priori: 12 items with >50 occurances
# It took 3.82 sec.

# %% [markdown]
# ### A-priori, s = 100

# %%
start = time.time()
N = 100  # frequency threshold

# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('A-priori: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 117 items with >100 occurances
# 426 items
# A-priori: 0 items with >100 occurances
# It took 0.84 sec.

# %% [markdown]
# As we increase the frequency threshold, the number of frequent items decreases and the time taken decreases.

# %% [markdown]
# ## PCY

# %% [markdown]
# ### PCY, N = 10

# %%
start = time.time()
import numpy as np
# hash table
N = 10

max_hash1 = 10*1000000
H1 = np.zeros((max_hash1,), dtype=int)
for key in readdata(k=2, report=False):
    hash_cell_1 = hash(key) % max_hash1
    H1[hash_cell_1] += 1
    
# compact hash table
H_good_1 = set(np.where(H1 >= N)[0])

del H1

# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # hash-based filtering stage from PCY
    hash_cell_1 = hash(key) % max_hash1
    if hash_cell_1 not in H_good_1:
        continue

    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('PCY: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 1733 items
# PCY: 1713 items with >10 occurances
# It took 36.25 sec.

# %% [markdown]
# ### PCY, N = 50

# %%
start = time.time()

# hash table
N = 50

max_hash1 = 10*1000000
H1 = np.zeros((max_hash1,), dtype=int)
for key in readdata(k=2, report=False):
    hash_cell_1 = hash(key) % max_hash1
    H1[hash_cell_1] += 1
    
# compact hash table
H_good_1 = set(np.where(H1 >= N)[0])

del H1


# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # hash-based filtering stage from PCY
    hash_cell_1 = hash(key) % max_hash1
    if hash_cell_1 not in H_good_1:
        continue

    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))


# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('PCY: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 521 items with >50 occurances
# 12 items
# PCY: 12 items with >50 occurances
# It took 4.39 sec.

# %% [markdown]
# ### PCY, N = 100

# %%
start = time.time()

# hash table
N = 100

max_hash1 = 10*1000000
H1 = np.zeros((max_hash1,), dtype=int)
for key in readdata(k=2, report=False):
    hash_cell_1 = hash(key) % max_hash1
    H1[hash_cell_1] += 1
    
# compact hash table
H_good_1 = set(np.where(H1 >= N)[0])

del H1


# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # hash-based filtering stage from PCY
    hash_cell_1 = hash(key) % max_hash1
    if hash_cell_1 not in H_good_1:
        continue

    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))


# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('PCY: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 117 items with >100 occurances
# 0 items
# PCY: 0 items with >100 occurances
# It took 1.64 sec.

# %% [markdown]
# As the frequency threshold increases, the number of frequent items and the time taken decreases.

# %% [markdown]
# ## 2. For the PCY algorithm, create up to 5 compact hash tables. What is  the difference in results and time of execution for 1,2,3,4 and 5 tables? Comment your results.

# %% [markdown]
# ### 1 table

# %%
start = time.time()
import numpy as np
# hash table
N = 10

max_hash1 = 10*1000000
H1 = np.zeros((max_hash1,), dtype=int)
for key in readdata(k=2, report=False):
    hash_cell_1 = hash(key) % max_hash1
    H1[hash_cell_1] += 1
    
# compact hash table
H_good_1 = set(np.where(H1 >= N)[0])

del H1

# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # hash-based filtering stage from PCY
    hash_cell_1 = hash(key) % max_hash1
    if hash_cell_1 not in H_good_1:
        continue

    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('PCY: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 1733 items
# PCY: 1713 items with >10 occurances
# It took 34.27 sec.

# %% [markdown]
# ### 2 tables

# %%
start = time.time()
import numpy as np
# hash table
N = 10

max_hash1 = 10*1000000
max_hash2 = 10*1000000+1000
H1 = np.zeros((max_hash1,), dtype=int)
H2 = np.zeros((max_hash2,), dtype=int)
for key in readdata(k=2, report=False):
    hash_cell_1 = hash(key) % max_hash1
    H1[hash_cell_1] += 1
    hash_cell_2 = hash(key) % max_hash2
    H2[hash_cell_2] += 1
    
# compact hash table
H_good_1 = set(np.where(H1 >= N)[0])
H_good_2 = set(np.where(H2 >= N)[0])

del H1
del H2
# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # hash-based filtering stage from PCY
    hash_cell_1 = hash(key) % max_hash1
    if hash_cell_1 not in H_good_1:
        continue
    hash_cell_2 = hash(key) % max_hash2
    if hash_cell_2 not in H_good_2:
        continue

    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('PCY: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 1713 items
# PCY: 1713 items with >10 occurances
# It took 80.48 sec.

# %% [markdown]
# ### 3 tables

# %%
start = time.time()
import numpy as np
# hash table
N = 10

max_hash1 = 10*1000000
max_hash2 = 10*1000000+1000
max_hash3 = 10*1000000+2000
H1 = np.zeros((max_hash1,), dtype=int)
H2 = np.zeros((max_hash2,), dtype=int)
H3 = np.zeros((max_hash3,), dtype=int)
for key in readdata(k=2, report=False):
    hash_cell_1 = hash(key) % max_hash1
    H1[hash_cell_1] += 1
    hash_cell_2 = hash(key) % max_hash2
    H2[hash_cell_2] += 1
    hash_cell_3 = hash(key) % max_hash3
    H3[hash_cell_3] += 1
    
# compact hash table
H_good_1 = set(np.where(H1 >= N)[0])
H_good_2 = set(np.where(H2 >= N)[0])
H_good_3 = set(np.where(H3 >= N)[0])

del H1
del H2
del H3
# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # hash-based filtering stage from PCY
    hash_cell_1 = hash(key) % max_hash1
    if hash_cell_1 not in H_good_1:
        continue
    hash_cell_2 = hash(key) % max_hash2
    if hash_cell_2 not in H_good_2:
        continue
        
    hash_cell_3 = hash(key) % max_hash3
    if hash_cell_3 not in H_good_3:
        continue

    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('PCY: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 1713 items
# PCY: 1713 items with >10 occurances
# It took 99.70 sec.

# %% [markdown]
# ### 4 tables

# %%
start = time.time()
import numpy as np
# hash table
N = 10

max_hash1 = 10*1000000
max_hash2 = 10*1000000+1000
max_hash3 = 10*1000000+2000
max_hash4 = 10*1000000+3000
H1 = np.zeros((max_hash1,), dtype=int)
H2 = np.zeros((max_hash2,), dtype=int)
H3 = np.zeros((max_hash3,), dtype=int)
H4 = np.zeros((max_hash4,), dtype=int)
for key in readdata(k=2, report=False):
    hash_cell_1 = hash(key) % max_hash1
    H1[hash_cell_1] += 1
    hash_cell_2 = hash(key) % max_hash2
    H2[hash_cell_2] += 1
    hash_cell_3 = hash(key) % max_hash3
    H3[hash_cell_3] += 1
    hash_cell_4 = hash(key) % max_hash4
    H4[hash_cell_4] += 1
    
# compact hash table
H_good_1 = set(np.where(H1 >= N)[0])
H_good_2 = set(np.where(H2 >= N)[0])
H_good_3 = set(np.where(H3 >= N)[0])
H_good_4 = set(np.where(H4 >= N)[0])

del H1
del H2
del H3
del H4
# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # hash-based filtering stage from PCY
    hash_cell_1 = hash(key) % max_hash1
    if hash_cell_1 not in H_good_1:
        continue
    hash_cell_2 = hash(key) % max_hash2
    if hash_cell_2 not in H_good_2:
        continue
        
    hash_cell_3 = hash(key) % max_hash3
    if hash_cell_3 not in H_good_3:
        continue
        
    hash_cell_4 = hash(key) % max_hash4
    if hash_cell_4 not in H_good_4:
        continue

    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('PCY: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 1713 items
# PCY: 1713 items with >10 occurances
# It took 102.78 sec.

# %% [markdown]
# ### 5 tables

# %%
start = time.time()
import numpy as np
# hash table
N = 10

max_hash1 = 10*1000000
max_hash2 = 10*1000000+1000
max_hash3 = 10*1000000+2000
max_hash4 = 10*1000000+3000
max_hash5 = 10*1000000+4000
H1 = np.zeros((max_hash1,), dtype=int)
H2 = np.zeros((max_hash2,), dtype=int)
H3 = np.zeros((max_hash3,), dtype=int)
H4 = np.zeros((max_hash4,), dtype=int)
H5 = np.zeros((max_hash5,), dtype=int)
for key in readdata(k=2, report=False):
    hash_cell_1 = hash(key) % max_hash1
    H1[hash_cell_1] += 1
    hash_cell_2 = hash(key) % max_hash2
    H2[hash_cell_2] += 1
    hash_cell_3 = hash(key) % max_hash3
    H3[hash_cell_3] += 1
    hash_cell_4 = hash(key) % max_hash4
    H4[hash_cell_4] += 1
    hash_cell_5 = hash(key) % max_hash5
    H5[hash_cell_5] += 1
    
# compact hash table
H_good_1 = set(np.where(H1 >= N)[0])
H_good_2 = set(np.where(H2 >= N)[0])
H_good_3 = set(np.where(H3 >= N)[0])
H_good_4 = set(np.where(H4 >= N)[0])
H_good_5 = set(np.where(H5 >= N)[0])

del H1
del H2
del H3
del H4
del H5
# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # hash-based filtering stage from PCY
    hash_cell_1 = hash(key) % max_hash1
    if hash_cell_1 not in H_good_1:
        continue
    hash_cell_2 = hash(key) % max_hash2
    if hash_cell_2 not in H_good_2:
        continue
        
    hash_cell_3 = hash(key) % max_hash3
    if hash_cell_3 not in H_good_3:
        continue
        
    hash_cell_4 = hash(key) % max_hash4
    if hash_cell_4 not in H_good_4:
        continue
        
    hash_cell_5 = hash(key) % max_hash5
    if hash_cell_5 not in H_good_5:
        continue

    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('PCY: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 1713 items
# PCY: 1713 items with >10 occurances
# It took 72.59 sec.

# %% [markdown]
# By increasing the number of hash tables, we reduce the amount of memory that we have to use, thus we are saving memory.
#
# The number of frequent items didn't change by increasing the number of hash tables.
#
# As we increase the number of hash tables it takes slightly more time.

# %% [markdown]
# ## 3. Find the final list of k-frequent items (k-tuples) for k=3 and 4. Experiment a bit and describe the best value for the support in each case. Warning: You can use any of the three algorithms, but be careful, because the algorithm can take too long if you don't chose it properly (well, basically don't use the naïve approach

# %%
# Frequent Items for k = 3

start = time.time()

N = 10  # frequency threshold

# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python


# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count

C3_items = set([a.union(b) for a in L2.keys() for b in L2.keys()]) # List comprehensions in python


# find frequent 2-tuples
C3 = {}
for key in readdata(k=3):
    # filter out non-frequent tuples
    if key not in C3_items:
        continue

    # record frequent tuples
    if key not in C3:
        C3[key] = 1
    else:
        C3[key] += 1
        
print("{} items".format(len(C3)))

# filter stage
L3 = {}
for key, count in C3.items():
    if count >= N:
        L3[key] = count
print('A-priori: {} items with >{} occurances'.format(len(L3), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 37555 items
# 2377 items
# A-priori: 343 items with >10 occurances
# It took 107.46 sec.

# %%
# Frequent Items for k = 4

start = time.time()

N = 10  # frequency threshold

# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python


# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count

C3_items = set([a.union(b) for a in L2.keys() for b in L2.keys()]) # List comprehensions in python


# find frequent 2-tuples
C3 = {}
for key in readdata(k=3):
    # filter out non-frequent tuples
    if key not in C3_items:
        continue

    # record frequent tuples
    if key not in C3:
        C3[key] = 1
    else:
        C3[key] += 1
        
print("{} items".format(len(C3)))

# filter stage
L3 = {}
for key, count in C3.items():
    if count >= N:
        L3[key] = count

C4_items = set([a.union(b) for a in L3.keys() for b in L3.keys()]) # List comprehensions in python


# find frequent 2-tuples
C4 = {}
for key in readdata(k=4):
    # filter out non-frequent tuples
    if key not in C4_items:
        continue

    # record frequent tuples
    if key not in C4:
        C4[key] = 1
    else:
        C4[key] += 1
        
print("{} items".format(len(C4)))

# filter stage
L4 = {}
for key, count in C4.items():
    if count >= N:
        L4[key] = count
print('A-priori: {} items with >{} occurances'.format(len(L4), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 37555 items
# 2377 items
# 291 items
# A-priori: 103 items with >10 occurances
# It took 113.26 sec.

# %% [markdown]
# ### Trying other support values

# %% [markdown]
# #### N = 20, k=3

# %%
start = time.time()

N = 20  # frequency threshold

# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python


# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count

C3_items = set([a.union(b) for a in L2.keys() for b in L2.keys()]) # List comprehensions in python


# find frequent 2-tuples
C3 = {}
for key in readdata(k=3):
    # filter out non-frequent tuples
    if key not in C3_items:
        continue

    # record frequent tuples
    if key not in C3:
        C3[key] = 1
    else:
        C3[key] += 1
        
print("{} items".format(len(C3)))

# filter stage
L3 = {}
for key, count in C3.items():
    if count >= N:
        L3[key] = count
print('A-priori: {} items with >{} occurances'.format(len(L3), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 1886 items with >20 occurances
# 16809 items
# 153 items
# A-priori: 8 items with >20 occurances
# It took 22.15 sec.

# %% [markdown]
# #### N = 20, k = 4

# %%
# Frequent Items for k = 4

start = time.time()

N = 20  # frequency threshold

# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python


# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count

C3_items = set([a.union(b) for a in L2.keys() for b in L2.keys()]) # List comprehensions in python


# find frequent 2-tuples
C3 = {}
for key in readdata(k=3):
    # filter out non-frequent tuples
    if key not in C3_items:
        continue

    # record frequent tuples
    if key not in C3:
        C3[key] = 1
    else:
        C3[key] += 1
        
print("{} items".format(len(C3)))

# filter stage
L3 = {}
for key, count in C3.items():
    if count >= N:
        L3[key] = count

C4_items = set([a.union(b) for a in L3.keys() for b in L3.keys()]) # List comprehensions in python


# find frequent 2-tuples
C4 = {}
for key in readdata(k=4):
    # filter out non-frequent tuples
    if key not in C4_items:
        continue

    # record frequent tuples
    if key not in C4:
        C4[key] = 1
    else:
        C4[key] += 1
        
print("{} items".format(len(C4)))

# filter stage
L4 = {}
for key, count in C4.items():
    if count >= N:
        L4[key] = count
print('A-priori: {} items with >{} occurances'.format(len(L4), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 1886 items with >20 occurances
# 16809 items
# 153 items
# 0 items
# A-priori: 0 items with >20 occurances
# It took 19.24 sec.

# %% [markdown]
# The best value for the support is 10 since when we decrease it the time taken increases a lot and when we increase it there are only few frequent items.
#
# With the support 10, we have 343 3-tuples frequent items and 103 4-tuples frequent items.

# %% [markdown]
# ## 4. Using one of the results of the previous items, for one k (k=2 or 3) find the possible clusters using the 1-NN criteria. Comment your results.
#
# > 1-NN means that if you have a tuple {A,B,C} and {C,E,F} then because they share one element {C}, then they belong to the same cluster  {A,B,C,E,F}.

# %% [markdown]
# #### k = 2, N = 10

# %%
start = time.time()
import numpy as np
# hash table
N = 10

max_hash1 = 10*1000000
max_hash2 = 10*1000000+1000
H1 = np.zeros((max_hash1,), dtype=int)
H2 = np.zeros((max_hash2,), dtype=int)
for key in readdata(k=2, report=False):
    hash_cell_1 = hash(key) % max_hash1
    H1[hash_cell_1] += 1
    hash_cell_2 = hash(key) % max_hash2
    H2[hash_cell_2] += 1
    
# compact hash table
H_good_1 = set(np.where(H1 >= N)[0])
H_good_2 = set(np.where(H2 >= N)[0])

del H1
del H2
# find frequent 1-tuples (individual items)
C1 = {}
for key in readdata(k=1, report=False):
    if key not in C1:
        C1[key] = 1
    else:
        C1[key] += 1    
        
print("{} items".format(len(C1)))

# filter stage
L1 = {}
for key, count in C1.items():
    if count >= N:
        L1[key] = count
print('{} items with >{} occurances'.format(len(L1), N))

C2_items = set([a.union(b) for a in L1.keys() for b in L1.keys()]) # List comprehensions in python

# find frequent 2-tuples
C2 = {}
for key in readdata(k=2):
    # hash-based filtering stage from PCY
    hash_cell_1 = hash(key) % max_hash1
    if hash_cell_1 not in H_good_1:
        continue
    hash_cell_2 = hash(key) % max_hash2
    if hash_cell_2 not in H_good_2:
        continue

    # filter out non-frequent tuples
    if key not in C2_items:
        continue

    # record frequent tuples
    if key not in C2:
        C2[key] = 1
    else:
        C2[key] += 1
        
print("{} items".format(len(C2)))

# filter stage
L2 = {}
for key, count in C2.items():
    if count >= N:
        L2[key] = count
print('PCY: {} items with >{} occurances'.format(len(L2), N))

end = time.time()
print('It took {:.2f} sec.'.format(end-start))
# Out:
# 74315 items
# 4316 items with >10 occurances
# 1713 items
# PCY: 1713 items with >10 occurances
# It took 70.76 sec.

# %%
L2
# Out:
# {frozenset({'Androutsopoulos Ion', 'Pavlopoulos John'}): 13,
#  frozenset({'Sumita Eiichiro', 'Utiyama Masao'}): 90,
#  frozenset({'Sumita Eiichiro', 'Watanabe Taro'}): 26,
#  frozenset({'Aguilar Gustavo', 'Solorio Thamar'}): 10,
#  frozenset({'Lam Wai', 'Zhang Wenxuan'}): 10,
#  frozenset({'Chersoni Emmanuele', 'Santus Enrico'}): 19,
#  frozenset({'Rashid Ahmad', 'Rezagholizadeh Mehdi'}): 10,
#  frozenset({'Sagot Beno{\\^\\i}t', "Seddah Djam{\\'e}"}): 15,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Chatterjee Rajen'}): 10,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Federmann Christian'}): 15,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Graham Yvette'}): 14,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Haddow Barry'}): 21,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Huck Matthias'}): 14,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Kocmi Tom'}): 13,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Koehn Philipp'}): 16,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Monz Christof'}): 13,
#  frozenset({'Chatterjee Rajen', 'Federmann Christian'}): 12,
#  frozenset({'Chatterjee Rajen', 'Graham Yvette'}): 10,
#  frozenset({'Chatterjee Rajen', 'Haddow Barry'}): 11,
#  frozenset({'Chatterjee Rajen', 'Huck Matthias'}): 11,
#  frozenset({'Chatterjee Rajen', 'Koehn Philipp'}): 11,
#  frozenset({'Chatterjee Rajen', 'Monz Christof'}): 10,
#  frozenset({'Chatterjee Rajen', 'Negri Matteo'}): 21,
#  frozenset({'Chatterjee Rajen', 'Turchi Marco'}): 21,
#  frozenset({'Federmann Christian', 'Graham Yvette'}): 12,
#  frozenset({'Federmann Christian', 'Haddow Barry'}): 17,
#  frozenset({'Federmann Christian', 'Huck Matthias'}): 12,
#  frozenset({'Federmann Christian', 'Koehn Philipp'}): 16,
#  frozenset({'Federmann Christian', 'Monz Christof'}): 14,
#  frozenset({'Federmann Christian', 'Negri Matteo'}): 10,
#  frozenset({'Federmann Christian', 'Turchi Marco'}): 10,
#  frozenset({'Freitag Markus', 'Huck Matthias'}): 17,
#  frozenset({'Graham Yvette', 'Haddow Barry'}): 13,
#  frozenset({'Graham Yvette', 'Huck Matthias'}): 10,
#  frozenset({'Graham Yvette', 'Koehn Philipp'}): 12,
#  frozenset({'Graham Yvette', 'Monz Christof'}): 10,
#  frozenset({'Grundkiewicz Roman', 'Heafield Kenneth'}): 12,
#  frozenset({'Haddow Barry', 'Huck Matthias'}): 17,
#  frozenset({'Haddow Barry', 'Koehn Philipp'}): 36,
#  frozenset({'Haddow Barry', 'Monz Christof'}): 15,
#  frozenset({'Huck Matthias', 'Koehn Philipp'}): 21,
#  frozenset({'Huck Matthias', 'Monz Christof'}): 10,
#  frozenset({'Knight Kevin', 'Koehn Philipp'}): 11,
#  frozenset({'Koehn Philipp', 'Monz Christof'}): 31,
#  frozenset({'Morishita Makoto', 'Nagata Masaaki'}): 10,
#  frozenset({'Negri Matteo', 'Turchi Marco'}): 71,
#  frozenset({'Pal Santanu', 'Zampieri Marcos'}): 10,
#  frozenset({'Chaudhary Vishrav', "Guzm{\\'a}n Francisco"}): 17,
#  frozenset({'Bogoychev Nikolay', 'Heafield Kenneth'}): 12,
#  frozenset({'Erdmann Grant', 'Gwinnup Jeremy'}): 14,
#  frozenset({'Anderson Tim', 'Gwinnup Jeremy'}): 10,
#  frozenset({'Escolano Carlos', "Fonollosa Jos{\\'e} A. R."}): 10,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Popel Martin'}): 13,
#  frozenset({'Li Zuchao', 'Zhao Hai'}): 19,
#  frozenset({'Utiyama Masao', 'Zhao Hai'}): 14,
#  frozenset({'Sumita Eiichiro', 'Zhao Hai'}): 12,
#  frozenset({'Li Lei', 'Wang Mingxuan'}): 24,
#  frozenset({'Li Lei', 'Zhou Hao'}): 19,
#  frozenset({'Shi Shuming', 'Wang Longyue'}): 11,
#  frozenset({'Tu Zhaopeng', 'Wang Longyue'}): 24,
#  frozenset({'Wang Longyue', 'Wang Xing'}): 10,
#  frozenset({'Shi Shuming', 'Tu Zhaopeng'}): 22,
#  frozenset({'Shi Shuming', 'Wang Xing'}): 13,
#  frozenset({'Tu Zhaopeng', 'Wang Xing'}): 19,
#  frozenset({'Shang Hengchao', 'Wei Daimeng'}): 10,
#  frozenset({'Wang Minghan', 'Wei Daimeng'}): 10,
#  frozenset({'Lei Lizhi', 'Wei Daimeng'}): 10,
#  frozenset({'Wei Daimeng', 'Yang Hao'}): 11,
#  frozenset({'Qin Ying', 'Wei Daimeng'}): 10,
#  frozenset({'Shang Hengchao', 'Wang Minghan'}): 10,
#  frozenset({'Lei Lizhi', 'Shang Hengchao'}): 10,
#  frozenset({'Shang Hengchao', 'Yang Hao'}): 11,
#  frozenset({'Qin Ying', 'Shang Hengchao'}): 10,
#  frozenset({'Guo Jiaxin', 'Yang Hao'}): 10,
#  frozenset({'Wang Minghan', 'Yang Hao'}): 15,
#  frozenset({'Qin Ying', 'Wang Minghan'}): 11,
#  frozenset({'Lei Lizhi', 'Yang Hao'}): 10,
#  frozenset({'Lei Lizhi', 'Qin Ying'}): 10,
#  frozenset({'Qin Ying', 'Yang Hao'}): 12,
#  frozenset({'Meng Fandong', 'Xu Jinan'}): 11,
#  frozenset({'Meng Fandong', 'Zhou Jie'}): 35,
#  frozenset({'Li Peng', 'Zhou Jie'}): 29,
#  frozenset({'Xu Jinan', 'Zhou Jie'}): 11,
#  frozenset({'Li Bei', 'Xiao Tong'}): 10,
#  frozenset({'Li Bei', 'Zhu Jingbo'}): 10,
#  frozenset({'Xiao Tong', 'Zhu Jingbo'}): 39,
#  frozenset({'Bandyopadhyay Sivaji', 'Pakray Partha'}): 12,
#  frozenset({'Dong Li', 'Wei Furu'}): 24,
#  frozenset({'Huang Shaohan', 'Wei Furu'}): 16,
#  frozenset({'Grundkiewicz Roman', 'Junczys-Dowmunt Marcin'}): 16,
#  frozenset({'Fraser Alexander', 'Hangya Viktor'}): 16,
#  frozenset({'Fraser Alexander', 'Stojanovski Dario'}): 12,
#  frozenset({'Fomicheva Marina', 'Specia Lucia'}): 17,
#  frozenset({"Blain Fr{\\'e}d{\\'e}ric", 'Specia Lucia'}): 21,
#  frozenset({'Neves Mariana', "N{\\'e}v{\\'e}ol Aur{\\'e}lie"}): 13,
#  frozenset({'Crego Josep', 'Senellart Jean'}): 17,
#  frozenset({'Chen Boxing', 'Luo Weihua'}): 13,
#  frozenset({'Federmann Christian', 'Post Matt'}): 12,
#  frozenset({'Koehn Philipp', 'Post Matt'}): 20,
#  frozenset({'Fujita Atsushi', 'Marie Benjamin'}): 17,
#  frozenset({'Li Liangyou', 'Liu Qun'}): 22,
#  frozenset({'Nakamura Satoshi', 'Sudoh Katsuhito'}): 17,
#  frozenset({'Chao Lidia S.', 'Wong Derek F.'}): 40,
#  frozenset({'Hu Junjie', 'Neubig Graham'}): 13,
#  frozenset({'Ding Chenchen', 'Nakazawa Toshiaki'}): 10,
#  frozenset({'Dabre Raj', 'Nakazawa Toshiaki'}): 11,
#  frozenset({'Mino Hideya', 'Nakazawa Toshiaki'}): 12,
#  frozenset({'Goto Isao', 'Nakazawa Toshiaki'}): 15,
#  frozenset({'Chu Chenhui', 'Nakazawa Toshiaki'}): 16,
#  frozenset({'Kurohashi Sadao', 'Nakazawa Toshiaki'}): 49,
#  frozenset({'Ding Chenchen', 'Goto Isao'}): 10,
#  frozenset({'Dabre Raj', 'Kunchukuttan Anoop'}): 10,
#  frozenset({'Dabre Raj', 'Kurohashi Sadao'}): 16,
#  frozenset({'Goto Isao', 'Mino Hideya'}): 17,
#  frozenset({'Kurohashi Sadao', 'Mino Hideya'}): 12,
#  frozenset({'Goto Isao', 'Kurohashi Sadao'}): 14,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Parida Shantipriya'}): 10,
#  frozenset({'Chu Chenhui', 'Kurohashi Sadao'}): 25,
#  frozenset({'Hirasawa Tosho', 'Komachi Mamoru'}): 11,
#  frozenset({'Imamura Kenji', 'Sumita Eiichiro'}): 21,
#  frozenset({'Kajiwara Tomoyuki', 'Komachi Mamoru'}): 13,
#  frozenset({'Bhattacharyya Pushpak', 'Ekbal Asif'}): 65,
#  frozenset({'Fi{\\v{s}}er Darja', "Ljube{\\v{s}}i{\\'c} Nikola"}): 17,
#  frozenset({'Collier Nigel', 'Pilehvar Mohammad Taher'}): 17,
#  frozenset({'Fornaciari Tommaso', 'Hovy Dirk'}): 11,
#  frozenset({'Abdelali Ahmed', 'Mubarak Hamdy'}): 24,
#  frozenset({'Abdelali Ahmed', 'Samih Younes'}): 11,
#  frozenset({'Abdelali Ahmed', 'Darwish Kareem'}): 19,
#  frozenset({'Mubarak Hamdy', 'Samih Younes'}): 11,
#  frozenset({'Darwish Kareem', 'Mubarak Hamdy'}): 27,
#  frozenset({'Darwish Kareem', 'Samih Younes'}): 10,
#  frozenset({'Abdul-Mageed Muhammad', 'Nagoudi El Moatez Billah'}): 10,
#  frozenset({'Bouamor Houda', 'Habash Nizar'}): 22,
#  frozenset({'Abbas Mourad', 'Lichouri Mohamed'}): 11,
#  frozenset({'Chakravarthi Bharathi Raja', 'Priyadharshini Ruba'}): 14,
#  frozenset({'Jauhiainen Heidi', 'Jauhiainen Tommi'}): 15,
#  frozenset({'Jauhiainen Heidi', "Lind{\\'e}n Krister"}): 15,
#  frozenset({'Jauhiainen Tommi', "Lind{\\'e}n Krister"}): 15,
#  frozenset({'Schlechtweg Dominik', 'Schulte im Walde Sabine'}): 10,
#  frozenset({'Buttery Paula', 'Caines Andrew'}): 18,
#  frozenset({'Horbach Andrea', 'Zesch Torsten'}): 10,
#  frozenset({"P{\\'e}rez-Ortiz Juan Antonio",
#             "S{\\'a}nchez-Mart{\\'\\i}nez Felipe"}): 14,
#  frozenset({'Gerdes Kim', 'Kahane Sylvain'}): 16,
#  frozenset({'Ji Heng', 'Li Manling'}): 13,
#  frozenset({'He Xiaodong', 'Zhou Bowen'}): 14,
#  frozenset({'Fried Daniel', 'Klein Dan'}): 10,
#  frozenset({'DeNero John', 'Klein Dan'}): 13,
#  frozenset({'Foster Jennifer', 'Wagner Joachim'}): 18,
#  frozenset({'Anastasopoulos Antonios', 'Neubig Graham'}): 21,
#  frozenset({'Cotterell Ryan', 'Williams Adina'}): 10,
#  frozenset({'Elazar Yanai', 'Goldberg Yoav'}): 11,
#  frozenset({'Goldberg Yoav', 'Ravfogel Shauli'}): 11,
#  frozenset({'Li Juanzi', 'Liu Zhiyuan'}): 21,
#  frozenset({'Khashabi Daniel', 'Roth Dan'}): 13,
#  frozenset({'Socher Richard', 'Xiong Caiming'}): 30,
#  frozenset({'Reichart Roi', "Vuli{\\'c} Ivan"}): 20,
#  frozenset({'Korhonen Anna', "Vuli{\\'c} Ivan"}): 48,
#  frozenset({'Korhonen Anna', 'Reichart Roi'}): 31,
#  frozenset({'Gardent Claire', 'Shimorina Anastasia'}): 10,
#  frozenset({'Baldwin Timothy', 'Mistica Meladel'}): 10,
#  frozenset({'Baldwin Timothy', 'Salehi Bahar'}): 13,
#  frozenset({'Cotterell Ryan', 'Vieira Tim'}): 10,
#  frozenset({'Van Durme Benjamin', 'Zhang Sheng'}): 14,
#  frozenset({'Van Durme Benjamin', 'White Aaron Steven'}): 17,
#  frozenset({'Gao Jianfeng', 'Peng Baolin'}): 12,
#  frozenset({'Gaido Marco', 'Negri Matteo'}): 12,
#  frozenset({'Gaido Marco', 'Turchi Marco'}): 12,
#  frozenset({'Bentivogli Luisa', 'Negri Matteo'}): 13,
#  frozenset({'Bentivogli Luisa', 'Turchi Marco'}): 10,
#  frozenset({'Guo Xiaoxiao', 'Yu Mo'}): 16,
#  frozenset({'Schwartz Roy', 'Smith Noah A.'}): 18,
#  frozenset({'Neubig Graham', 'Rijhwani Shruti'}): 11,
#  frozenset({'Frank Anette', 'Opitz Juri'}): 11,
#  frozenset({'Inui Kentaro', 'Ouchi Hiroki'}): 13,
#  frozenset({'Inui Kentaro', 'Suzuki Jun'}): 27,
#  frozenset({'Inui Kentaro', 'Kobayashi Sosuke'}): 10,
#  frozenset({'Inui Kentaro', 'Yokoi Sho'}): 10,
#  frozenset({'Inui Kentaro', 'Kuribayashi Tatsuki'}): 12,
#  frozenset({'Chersoni Emmanuele', 'Lenci Alessandro'}): 15,
#  frozenset({'Blache Philippe', 'Chersoni Emmanuele'}): 10,
#  frozenset({'Lenci Alessandro', 'Santus Enrico'}): 16,
#  frozenset({'Blache Philippe', 'Lenci Alessandro'}): 11,
#  frozenset({'Dagan Ido', 'Shwartz Vered'}): 16,
#  frozenset({'Dagan Ido', 'Stanovsky Gabriel'}): 17,
#  frozenset({'Eger Steffen', 'Zhao Wei'}): 11,
#  frozenset({'Augenstein Isabelle', 'Bjerva Johannes'}): 15,
#  frozenset({'Barrett Maria', 'S{\\o}gaard Anders'}): 14,
#  frozenset({'Dagan Ido', 'Goldberger Jacob'}): 20,
#  frozenset({'Cui Yiming', 'Liu Ting'}): 17,
#  frozenset({'Cui Yiming', 'Wang Shijin'}): 18,
#  frozenset({'Cui Yiming', 'Hu Guoping'}): 14,
#  frozenset({'Che Wanxiang', 'Liu Ting'}): 77,
#  frozenset({'Che Wanxiang', 'Wang Shijin'}): 10,
#  frozenset({'Liu Ting', 'Wang Shijin'}): 20,
#  frozenset({'Hu Guoping', 'Liu Ting'}): 20,
#  frozenset({'Hu Guoping', 'Wang Shijin'}): 18,
#  frozenset({'Groschwitz Jonas', 'Koller Alexander'}): 11,
#  frozenset({'Fohr Dominique', 'Illina Irina'}): 10,
#  frozenset({'Gonzalez-Hernandez Graciela', 'Weissenbacher Davy'}): 10,
#  frozenset({'Chen Yubo', 'Liu Kang'}): 32,
#  frozenset({'Chen Yubo', 'Zhao Jun'}): 35,
#  frozenset({'Liu Kang', 'Zhao Jun'}): 75,
#  frozenset({'Liu Kang', 'Liu Shengping'}): 10,
#  frozenset({'Liu Shengping', 'Zhao Jun'}): 10,
#  frozenset({'Chakravarthi Bharathi Raja', 'McCrae John P.'}): 10,
#  frozenset({'Cotterell Ryan', 'Vylomova Ekaterina'}): 13,
#  frozenset({'Nicolai Garrett', 'Silfverberg Miikka'}): 10,
#  frozenset({'Hulden Mans', 'Silfverberg Miikka'}): 17,
#  frozenset({'Cotterell Ryan', 'Pimentel Tiago'}): 21,
#  frozenset({'Cotterell Ryan', 'Mielke Sabrina J.'}): 12,
#  frozenset({'Habash Nizar', 'Khalifa Salam'}): 16,
#  frozenset({'Cotterell Ryan', 'Hulden Mans'}): 10,
#  frozenset({'Kozareva Zornitsa', 'Ravi Sujith'}): 13,
#  frozenset({'Nakamura Satoshi', 'Yoshino Koichiro'}): 19,
#  frozenset({'Chen Nancy', 'Liu Zhengyuan'}): 10,
#  frozenset({'Fung Pascale', 'Winata Genta Indra'}): 26,
#  frozenset({'Majumder Navonil', 'Poria Soujanya'}): 12,
#  frozenset({'Mihalcea Rada', 'Poria Soujanya'}): 11,
#  frozenset({'Minker Wolfgang', 'Ultes Stefan'}): 18,
#  frozenset({'Eskenazi Maxine', 'Mehri Shikib'}): 10,
#  frozenset({'Fung Pascale', 'Madotto Andrea'}): 27,
#  frozenset({'Da San Martino Giovanni', 'Nakov Preslav'}): 25,
#  frozenset({'Chamberlain Jon', 'Poesio Massimo'}): 11,
#  frozenset({'Nguyen Thien Huu', 'Pouran Ben Veyseh Amir'}): 13,
#  frozenset({'Dernoncourt Franck', 'Nguyen Thien Huu'}): 11,
#  frozenset({'Wang Jin', 'Zhang Xuejie'}): 30,
#  frozenset({'Lu Qin', 'Xiang Rong'}): 10,
#  frozenset({'Huang Chu-Ren', 'Xiang Rong'}): 10,
#  frozenset({'Chersoni Emmanuele', 'Huang Chu-Ren'}): 14,
#  frozenset({'Li Wenjie', 'Lu Qin'}): 22,
#  frozenset({'Huang Chu-Ren', 'Lu Qin'}): 15,
#  frozenset({'Hauer Bradley', 'Kondrak Grzegorz'}): 20,
#  frozenset({'Bansal Mohit', 'Pasunuru Ramakanth'}): 19,
#  frozenset({'Chen Kuan-Yu', 'Wang Hsin-Min'}): 15,
#  frozenset({'Chen Berlin', 'Lo Tien-Hong'}): 10,
#  frozenset({'Lee Lung-Hao', 'Tseng Yuen-Hsien'}): 11,
#  frozenset({'Weeds Julie', 'Weir David'}): 15,
#  frozenset({'Liu Zihan', 'Winata Genta Indra'}): 16,
#  frozenset({'Fung Pascale', 'Liu Zihan'}): 22,
#  frozenset({'Madotto Andrea', 'Winata Genta Indra'}): 13,
#  frozenset({'Luo Fuli', 'Yang Pengcheng'}): 11,
#  frozenset({'Liu Tianyu', 'Sui Zhifang'}): 14,
#  frozenset({'Chang Baobao', 'Liu Tianyu'}): 15,
#  frozenset({'Chang Baobao', 'Sui Zhifang'}): 33,
#  frozenset({'Fung Pascale', 'Xu Peng'}): 14,
#  frozenset({'Rei Marek', 'Yannakoudakis Helen'}): 10,
#  frozenset({'Galitsky Boris', 'Ilvovsky Dmitry'}): 17,
#  frozenset({'Georgiev Georgi', 'Nakov Preslav'}): 11,
#  frozenset({'Koychev Ivan', 'Nakov Preslav'}): 15,
#  frozenset({'Angelova Galia', 'Boytcheva Svetla'}): 10,
#  frozenset({'Costa-juss{\\`a} Marta R.', 'Escolano Carlos'}): 11,
#  frozenset({'Kamigaito Hidetaka', 'Okumura Manabu'}): 27,
#  frozenset({'Espa{\\~n}a-Bonet Cristina', 'van Genabith Josef'}): 10,
#  frozenset({'Kamigaito Hidetaka', 'Takamura Hiroya'}): 18,
#  frozenset({'Okumura Manabu', 'Takamura Hiroya'}): 44,
#  frozenset({'Lee John', 'Yeung Chak Yan'}): 12,
#  frozenset({'Gravier Guillaume', "S{\\'e}billot Pascale"}): 12,
#  frozenset({'Osenova Petya', 'Simov Kiril'}): 51,
#  frozenset({'Poncelas Alberto', 'Way Andy'}): 12,
#  frozenset({'Popescu Octavian', 'Vo Ngoc Phuoc An'}): 15,
#  frozenset({'Cabrio Elena', 'Villata Serena'}): 14,
#  frozenset({'Ninomiya Takashi', 'Tamura Akihiro'}): 12,
#  frozenset({'Glass James', 'Mohtarami Mitra'}): 10,
#  frozenset({'Glass James', 'Nakov Preslav'}): 10,
#  frozenset({'Zhang Zhuosheng', 'Zhao Hai'}): 17,
#  frozenset({'Kato Yoshihide', 'Matsubara Shigeki'}): 15,
#  frozenset({'Ginter Filip', 'Pyysalo Sampo'}): 12,
#  frozenset({'Ginter Filip', 'Kanerva Jenna'}): 19,
#  frozenset({'Velldal Erik', '{\\O}vrelid Lilja'}): 31,
#  frozenset({'Oepen Stephan', 'Velldal Erik'}): 16,
#  frozenset({'Oepen Stephan', '{\\O}vrelid Lilja'}): 12,
#  frozenset({'Anderson Mark', "G{\\'o}mez-Rodr{\\'\\i}guez Carlos"}): 10,
#  frozenset({'Chang Walter', 'Dernoncourt Franck'}): 18,
#  frozenset({'Lin Jimmy', 'Xin Ji'}): 11,
#  frozenset({'Bouillon Pierrette', 'Gerlach Johanna'}): 14,
#  frozenset({'Bouillon Pierrette', 'Tsourakis Nikos'}): 10,
#  frozenset({'Mihalcea Rada', "P{\\'e}rez-Rosas Ver{\\'o}nica"}): 23,
#  frozenset({'Lin Zhaojiang', 'Winata Genta Indra'}): 12,
#  frozenset({'Lin Zhaojiang', 'Madotto Andrea'}): 16,
#  frozenset({'Fung Pascale', 'Lin Zhaojiang'}): 19,
#  frozenset({'Wang Haifeng', 'Wu Hua'}): 68,
#  frozenset({'Baldwin Timothy', 'Lau Jey Han'}): 35,
#  frozenset({'Lebanoff Logan', 'Liu Fei'}): 11,
#  frozenset({'Bernardy Jean-Philippe', 'Chatzikyriakidis Stergios'}): 10,
#  frozenset({'Dalvi Fahim', 'Sajjad Hassan'}): 17,
#  frozenset({'Durrani Nadir', 'Sajjad Hassan'}): 29,
#  frozenset({'Dalvi Fahim', 'Durrani Nadir'}): 16,
#  frozenset({'Bui Trung', 'Dernoncourt Franck'}): 16,
#  frozenset({'Pustejovsky James', 'Verhagen Marc'}): 28,
#  frozenset({'Kaneko Masahiro', 'Komachi Mamoru'}): 15,
#  frozenset({'Ananiadou Sophia', 'Miwa Makoto'}): 11,
#  frozenset({'Han Jiawei', 'Ji Heng'}): 22,
#  frozenset({'Ning Qiang', 'Roth Dan'}): 19,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Specia Lucia'}): 11,
#  frozenset({'Demeester Thomas', 'Develder Chris'}): 14,
#  frozenset({'Androutsopoulos Ion', 'Malakasiotis Prodromos'}): 16,
#  frozenset({'Gurevych Iryna', 'Reimers Nils'}): 11,
#  frozenset({'Daxenberger Johannes', 'Gurevych Iryna'}): 13,
#  frozenset({'Conia Simone', 'Navigli Roberto'}): 10,
#  frozenset({'Cohen Shay B.', 'Lapata Mirella'}): 12,
#  frozenset({'Cheng Yu', 'Gan Zhe'}): 13,
#  frozenset({'Gan Zhe', 'Liu Jingjing'}): 14,
#  frozenset({'Cheng Yu', 'Liu Jingjing'}): 12,
#  frozenset({'Radev Dragomir', 'Zhang Rui'}): 15,
#  frozenset({'Radev Dragomir', 'Yu Tao'}): 12,
#  frozenset({'Yu Tao', 'Zhang Rui'}): 10,
#  frozenset({'Neubig Graham', 'Wang Xinyi'}): 10,
#  frozenset({'Ruppenhofer Josef', 'Wiegand Michael'}): 22,
#  frozenset({'Krahmer Emiel', 'van der Lee Chris'}): 10,
#  frozenset({'Zeng Michael', 'Zhu Chenguang'}): 13,
#  frozenset({'Cardie Claire', 'Du Xinya'}): 10,
#  frozenset({'Morency Louis-Philippe', 'Poria Soujanya'}): 10,
#  frozenset({'Jiang Haoming', 'Zhao Tuo'}): 11,
#  frozenset({'Gao Jianfeng', 'Liu Xiaodong'}): 23,
#  frozenset({'Cherry Colin', 'Foster George'}): 14,
#  frozenset({'Glass Michael', 'Gliozzo Alfio'}): 10,
#  frozenset({'Khot Tushar', 'Sabharwal Ashish'}): 19,
#  frozenset({'Xia Congying', 'Yu Philip'}): 10,
#  frozenset({'Huang Xuanjing', 'Zhang Qi'}): 41,
#  frozenset({'Huang Xuanjing', 'Liu Pengfei'}): 16,
#  frozenset({'Xu Kun', 'Yu Dong'}): 10,
#  frozenset({'Hirao Tsutomu', 'Nagata Masaaki'}): 22,
#  frozenset({'Feng Yansong', 'Zhao Dongyan'}): 29,
#  frozenset({'Yan Rui', 'Zhao Dongyan'}): 26,
#  frozenset({'Duan Nan', 'Gong Yeyun'}): 14,
#  frozenset({'Huang Xuanjing', 'Wei Zhongyu'}): 20,
#  frozenset({'Suleman Kaheer', 'Trischler Adam'}): 10,
#  frozenset({'Li Zhenghua', 'Zhang Min'}): 33,
#  frozenset({'Zhang Min', 'Zhang Yue'}): 13,
#  frozenset({'Qiu Xipeng', 'Yan Hang'}): 10,
#  frozenset({'Liu Pengfei', 'Qiu Xipeng'}): 16,
#  frozenset({'Ren Xuancheng', 'Sun Xu'}): 20,
#  frozenset({'Su Qi', 'Sun Xu'}): 11,
#  frozenset({'Wu Chuhan', 'Wu Fangzhao'}): 28,
#  frozenset({'Huang Yongfeng', 'Wu Chuhan'}): 29,
#  frozenset({'Huang Yongfeng', 'Wu Fangzhao'}): 27,
#  frozenset({'Dernoncourt Franck', 'Kim Doo Soon'}): 12,
#  frozenset({'Bui Trung', 'Kim Doo Soon'}): 11,
#  frozenset({'Liang Paul Pu', 'Morency Louis-Philippe'}): 14,
#  frozenset({'Ge Tao', 'Wei Furu'}): 14,
#  frozenset({'Wei Furu', 'Xu Ke'}): 15,
#  frozenset({'Sawhney Ramit', 'Shah Rajiv Ratn'}): 15,
#  frozenset({'Chen Guanyi', 'Lin Chenghua'}): 10,
#  frozenset({'Hovy Dirk', 'Plank Barbara'}): 14,
#  frozenset({'Ahmad Wasi', 'Chang Kai-Wei'}): 10,
#  frozenset({'Neubig Graham', 'Yin Pengcheng'}): 10,
#  frozenset({'Song Yan', 'Tian Yuanhe'}): 20,
#  frozenset({'Dinan Emily', 'Weston Jason'}): 10,
#  frozenset({'Batra Dhruv', 'Parikh Devi'}): 13,
#  frozenset({'Bui Trung', 'Chang Walter'}): 13,
#  frozenset({'Wei Furu', 'Zhou Ming'}): 51,
#  frozenset({'Yang Nan', 'Zhou Ming'}): 11,
#  frozenset({'He Keqing', 'Yan Yuanmeng'}): 10,
#  frozenset({'Xu Weiran', 'Yan Yuanmeng'}): 12,
#  frozenset({'He Keqing', 'Xu Weiran'}): 11,
#  frozenset({'Black Alan W', 'Prabhumoye Shrimai'}): 11,
#  frozenset({'Qin Tao', 'Wu Lijun'}): 10,
#  frozenset({'Liu Tie-Yan', 'Qin Tao'}): 18,
#  frozenset({'Chang Kai-Wei', 'Zhao Jieyu'}): 13,
#  frozenset({'Chen Kehai', 'Wang Rui'}): 17,
#  frozenset({'Utiyama Masao', 'Wang Rui'}): 26,
#  frozenset({'Sumita Eiichiro', 'Wang Rui'}): 25,
#  frozenset({'Chen Kehai', 'Utiyama Masao'}): 15,
#  frozenset({'Chen Kehai', 'Sumita Eiichiro'}): 15,
#  frozenset({'Sumita Eiichiro', 'Zhao Tiejun'}): 12,
#  frozenset({'Zhang Dongdong', 'Zhou Ming'}): 23,
#  frozenset({'Li Zhoujun', 'Zhou Ming'}): 11,
#  frozenset({'Bansal Mohit', 'Nie Yixin'}): 10,
#  frozenset({'Riedel Sebastian', 'Stenetorp Pontus'}): 17,
#  frozenset({'Poesio Massimo', 'Yu Juntao'}): 12,
#  frozenset({'Han Jiawei', 'Ren Xiang'}): 13,
#  frozenset({'Chakrabarty Tuhin', 'Muresan Smaranda'}): 14,
#  frozenset({'Choi Yejin', 'Le Bras Ronan'}): 11,
#  frozenset({'Bhagavatula Chandra', 'Choi Yejin'}): 14,
#  frozenset({'Hu Zhiting', 'Xing Eric'}): 13,
#  frozenset({'Bosselut Antoine', 'Choi Yejin'}): 14,
#  frozenset({'Biemann Chris', 'Yimam Seid Muhie'}): 19,
#  frozenset({'Dasigi Pradeep', 'Gardner Matt'}): 12,
#  frozenset({'Lin Bill Yuchen', 'Ren Xiang'}): 16,
#  frozenset({'Cohen William', 'Dhingra Bhuwan'}): 11,
#  frozenset({'Boyd-Graber Jordan', "Daum{\\'e} III Hal"}): 13,
#  frozenset({'Liu Bing', 'Xu Hu'}): 15,
#  frozenset({'Celikyilmaz Asli', 'Gao Jianfeng'}): 13,
#  frozenset({'Choi Yejin', 'Holtzman Ari'}): 12,
#  frozenset({'Brockett Chris', 'Zhang Yizhe'}): 11,
#  frozenset({'Dolan Bill', 'Zhang Yizhe'}): 10,
#  frozenset({'Brockett Chris', 'Dolan Bill'}): 19,
#  frozenset({'Barzilay Regina', 'Lei Tao'}): 13,
#  frozenset({'Brockett Chris', 'Galley Michel'}): 15,
#  frozenset({'Galley Michel', 'Gao Jianfeng'}): 16,
#  frozenset({'Dolan Bill', 'Galley Michel'}): 15,
#  frozenset({'Brockett Chris', 'Gao Jianfeng'}): 14,
#  frozenset({'Dolan Bill', 'Gao Jianfeng'}): 13,
#  frozenset({'Nallapati Ramesh', 'Xiang Bing'}): 15,
#  frozenset({'Wei Zhongyu', 'Zhang Qi'}): 13,
#  frozenset({'Kurohashi Sadao', 'Murawaki Yugo'}): 15,
#  frozenset({'Chen Lu', 'Yu Kai'}): 17,
#  frozenset({'Yu Kai', 'Zhu Su'}): 11,
#  frozenset({'Liu Zhiyuan', 'Yao Yuan'}): 10,
#  frozenset({'Sun Maosong', 'Yao Yuan'}): 10,
#  frozenset({'Han Xu', 'Liu Zhiyuan'}): 29,
#  frozenset({'Han Xu', 'Sun Maosong'}): 22,
#  frozenset({'Liu Zhiyuan', 'Sun Maosong'}): 70,
#  frozenset({'He Xiaodong', 'Wu Youzheng'}): 11,
#  frozenset({'Bhattacharyya Pushpak', 'Saha Sriparna'}): 17,
#  frozenset({'Dai Xinyu', 'Huang Shujian'}): 15,
#  frozenset({'Chen Jiajun', 'Huang Shujian'}): 34,
#  frozenset({'Chen Jiajun', 'Dai Xinyu'}): 19,
#  frozenset({'Lin Yankai', 'Sun Maosong'}): 20,
#  frozenset({'Chen Wenhu', 'Wang William Yang'}): 13,
#  frozenset({'Wang William Yang', 'Xiong Wenhan'}): 15,
#  frozenset({'Chiticariu Laura', 'Li Yunyao'}): 14,
#  frozenset({'Liu Tingwen', 'Yu Bowen'}): 15,
#  frozenset({'Ji Heng', 'Lin Ying'}): 16,
#  frozenset({'Chang Shih-Fu', 'Ji Heng'}): 13,
#  frozenset({'Ji Heng', 'Voss Clare'}): 12,
#  frozenset({'Ji Heng', 'Pan Xiaoman'}): 18,
#  frozenset({'Brown Susan Windisch', 'Palmer Martha'}): 10,
#  frozenset({'Bhat Suma', 'Gong Hongyu'}): 10,
#  frozenset({'Alva-Manchego Fernando', 'Specia Lucia'}): 10,
#  frozenset({'Gaspari Federico', 'Way Andy'}): 10,
#  frozenset({'Birch Alexandra', 'Haddow Barry'}): 18,
#  frozenset({'Bonial Claire', 'Voss Clare'}): 10,
#  frozenset({'Camacho-Collados Jose', 'Pilehvar Mohammad Taher'}): 12,
#  frozenset({'Kennington Casey', 'Schlangen David'}): 15,
#  frozenset({'Mineshima Koji', 'Yanaka Hitomi'}): 11,
#  frozenset({'Bekki Daisuke', 'Mineshima Koji'}): 19,
#  frozenset({'Bali Kalika', 'Choudhury Monojit'}): 29,
#  frozenset({'Navarretta Costanza', 'Paggio Patrizia'}): 10,
#  frozenset({'Rehbein Ines', 'Ruppenhofer Josef'}): 15,
#  frozenset({'Wisniewski Guillaume', 'Yvon Fran{\\c{c}}ois'}): 38,
#  frozenset({'Claveau Vincent', 'Kijak Ewa'}): 10,
#  frozenset({'Besan{\\c{c}}on Romaric', 'Ferret Olivier'}): 19,
#  frozenset({'Ferret Olivier', 'Grau Brigitte'}): 15,
#  frozenset({'Nakamura Satoshi', 'Sakti Sakriani'}): 30,
#  frozenset({'Costa-juss{\\`a} Marta R.', "Fonollosa Jos{\\'e} A. R."}): 32,
#  frozenset({'Pino Juan', 'Wang Changhan'}): 10,
#  frozenset({'Sennrich Rico', 'Zhang Biao'}): 10,
#  frozenset({'Ney Hermann', 'Wang Weiyue'}): 14,
#  frozenset({'Khadivi Shahram', 'Ney Hermann'}): 10,
#  frozenset({'Guillaume Bruno', 'Perrier Guy'}): 17,
#  frozenset({'Tu Kewei', 'Wang Xinyu'}): 11,
#  frozenset({'Jiang Yong', 'Tu Kewei'}): 25,
#  frozenset({'Postma Marten', 'Vossen Piek'}): 14,
#  frozenset({'Huang Minlie', 'Zhu Xiaoyan'}): 34,
#  frozenset({'Beck Daniel', 'Cohn Trevor'}): 10,
#  frozenset({'Miyao Yusuke', 'Noji Hiroshi'}): 12,
#  frozenset({'Gangal Varun', 'Hovy Eduard'}): 12,
#  frozenset({'Bos Johan', 'van Noord Rik'}): 12,
#  frozenset({'Arcan Mihael', 'Buitelaar Paul'}): 21,
#  frozenset({'Litvak Marina', 'Vanetik Natalia'}): 14,
#  frozenset({'El-Haj Mahmoud', 'Rayson Paul'}): 13,
#  frozenset({'Yu Dian', 'Yu Dong'}): 10,
#  frozenset({'Liu Lemao', 'Shi Shuming'}): 12,
#  frozenset({'Duan Nan', 'Tang Duyu'}): 20,
#  frozenset({'Gong Ming', 'Shou Linjun'}): 16,
#  frozenset({'Jiang Daxin', 'Shou Linjun'}): 14,
#  frozenset({'Duan Nan', 'Shou Linjun'}): 10,
#  frozenset({'Gong Ming', 'Jiang Daxin'}): 15,
#  frozenset({'Duan Nan', 'Gong Ming'}): 11,
#  frozenset({'Duan Nan', 'Jiang Daxin'}): 20,
#  frozenset({'He Zhongjun', 'Wu Hua'}): 16,
#  frozenset({'He Zhongjun', 'Wang Haifeng'}): 12,
#  frozenset({'Li Peng', 'Lin Yankai'}): 17,
#  frozenset({'Lin Yankai', 'Zhou Jie'}): 16,
#  frozenset({'Arase Yuki', 'Kajiwara Tomoyuki'}): 14,
#  frozenset({'Chen Yufeng', 'Xu Jinan'}): 22,
#  frozenset({'Abdelali Ahmed', 'Sajjad Hassan'}): 15,
#  frozenset({'Abdelali Ahmed', 'Durrani Nadir'}): 11,
#  frozenset({'Duh Kevin', 'Koehn Philipp'}): 13,
#  frozenset({'Duan Nan', 'Zhou Ming'}): 39,
#  frozenset({'Zhang Jiajun', 'Zong Chengqing'}): 48,
#  frozenset({'Hong Yu', 'Zhou Guodong'}): 10,
#  frozenset({'Kong Fang', 'Zhou Guodong'}): 16,
#  frozenset({'Qi Tao', 'Wu Fangzhao'}): 15,
#  frozenset({'Qi Tao', 'Wu Chuhan'}): 19,
#  frozenset({'Huang Yongfeng', 'Qi Tao'}): 18,
#  frozenset({'Wu Fangzhao', 'Xie Xing'}): 14,
#  frozenset({'Wu Chuhan', 'Xie Xing'}): 12,
#  frozenset({'Du{\\v{s}}ek Ond{\\v{r}}ej', 'Rieser Verena'}): 13,
#  frozenset({'Choubey Prafulla Kumar', 'Huang Ruihong'}): 11,
#  frozenset({'Ekbal Asif', 'Gupta Deepak'}): 11,
#  frozenset({'Meng Fandong', 'Zhang Jinchao'}): 10,
#  frozenset({'Zhang Jinchao', 'Zhou Jie'}): 21,
#  frozenset({'Clark Peter', 'Tandon Niket'}): 10,
#  frozenset({'Jiang Xin', 'Shang Lifeng'}): 11,
#  frozenset({'Liu Qun', 'Shang Lifeng'}): 10,
#  frozenset({'Jiang Xin', 'Liu Qun'}): 15,
#  frozenset({'Scialom Thomas', 'Staiano Jacopo'}): 11,
#  frozenset({'Al Khatib Khalid', 'Stein Benno'}): 11,
#  frozenset({'Stein Benno', 'Wachsmuth Henning'}): 34,
#  frozenset({'Bing Lidong', 'Lam Wai'}): 19,
#  frozenset({'Wang Longyue', 'Wong Derek F.'}): 15,
#  frozenset({'Chao Lidia S.', 'Wang Longyue'}): 13,
#  frozenset({'Lin Hongfei', 'Yang Liang'}): 13,
#  frozenset({'Liu Yang', 'Sun Maosong'}): 30,
#  frozenset({'Shutova Ekaterina', 'Yannakoudakis Helen'}): 11,
#  frozenset({'Shi Weiyan', 'Yu Zhou'}): 10,
#  frozenset({'Popel Martin', "{\\v{Z}}abokrtsk{\\'y} Zden{\\v{e}}k"}): 12,
#  frozenset({'Zeman Daniel', "{\\v{Z}}abokrtsk{\\'y} Zden{\\v{e}}k"}): 10,
#  frozenset({'He Pengcheng', 'Liu Xiaodong'}): 11,
#  frozenset({'Chen Weizhu', 'Liu Xiaodong'}): 12,
#  frozenset({'Chen Weizhu', 'He Pengcheng'}): 12,
#  frozenset({'Gao Jianfeng', 'He Pengcheng'}): 10,
#  frozenset({'Chen Weizhu', 'Gao Jianfeng'}): 12,
#  frozenset({'Cotterell Ryan', 'Eisner Jason'}): 18,
#  frozenset({'Cotterell Ryan', 'Meister Clara'}): 12,
#  frozenset({'Marrese-Taylor Edison', 'Matsuo Yutaka'}): 16,
#  frozenset({'Qin Tao', 'Tan Xu'}): 10,
#  frozenset({'Liu Tie-Yan', 'Tan Xu'}): 11,
#  frozenset({'Jin Lifeng', 'Schuler William'}): 13,
#  frozenset({'Toyoda Masashi', 'Yoshinaga Naoki'}): 14,
#  frozenset({'He Yulan', 'Zhou Deyu'}): 21,
#  frozenset({'Kitsuregawa Masaru', 'Yoshinaga Naoki'}): 15,
#  frozenset({'Ponti Edoardo Maria', "Vuli{\\'c} Ivan"}): 18,
#  frozenset({'Korhonen Anna', 'Ponti Edoardo Maria'}): 18,
#  frozenset({'Glava{\\v{s}} Goran', "Vuli{\\'c} Ivan"}): 28,
#  frozenset({'Glava{\\v{s}} Goran', 'Korhonen Anna'}): 13,
#  frozenset({'Glava{\\v{s}} Goran', 'Lauscher Anne'}): 11,
#  frozenset({'Okazaki Naoaki', 'Takase Sho'}): 15,
#  frozenset({'Jiang Daxin', 'Zhou Ming'}): 10,
#  frozenset({'Baldwin Timothy', 'Cohn Trevor'}): 37,
#  frozenset({'Hovy Eduard', 'Mitamura Teruko'}): 20,
#  frozenset({'Liu Qian', 'Lou Jian-Guang'}): 10,
#  frozenset({'Liu Shujie', 'Zhou Ming'}): 34,
#  frozenset({'Han Xu', 'Lin Yankai'}): 10,
#  frozenset({'Han Xu', 'Li Peng'}): 12,
#  frozenset({'Han Xu', 'Zhou Jie'}): 11,
#  frozenset({'Lin Yankai', 'Liu Zhiyuan'}): 24,
#  frozenset({'Li Peng', 'Liu Zhiyuan'}): 17,
#  frozenset({'Liu Zhiyuan', 'Zhou Jie'}): 15,
#  frozenset({'Li Peng', 'Sun Maosong'}): 17,
#  frozenset({'Sun Maosong', 'Zhou Jie'}): 11,
#  frozenset({'Tang Duyu', 'Zhou Ming'}): 21,
#  frozenset({'El-Kishky Ahmed', "Guzm{\\'a}n Francisco"}): 10,
#  frozenset({'Kim Young-Bum', 'Sarikaya Ruhi'}): 18,
#  frozenset({'Wen Ji-Rong', 'Zhao Wayne Xin'}): 11,
#  frozenset({'Liu Zhiyuan', 'Qi Fanchao'}): 12,
#  frozenset({'Qi Fanchao', 'Sun Maosong'}): 12,
#  frozenset({'Huang Minlie', 'Takanobu Ryuichi'}): 10,
#  frozenset({'Qu Weiguang', 'Zhou Junsheng'}): 10,
#  frozenset({'Matsumoto Yuji', 'Shindo Hiroyuki'}): 29,
#  frozenset({'Cao Pengfei', 'Chen Yubo'}): 10,
#  frozenset({'Cao Pengfei', 'Liu Kang'}): 10,
#  frozenset({'Cao Pengfei', 'Zhao Jun'}): 11,
#  frozenset({'He Xiaofeng', 'Wang Chengyu'}): 10,
#  frozenset({'Miwa Makoto', 'Sasaki Yutaka'}): 11,
#  frozenset({'Sennrich Rico', 'Titov Ivan'}): 16,
#  frozenset({'Bhattacharyya Pushpak', 'Kanojia Diptesh'}): 32,
#  frozenset({'Duan Xiangyu', 'Zhang Min'}): 19,
#  frozenset({'Liu Xiaozhong', 'Sun Changlong'}): 13,
#  frozenset({'Ghosh Debanjan', 'Muresan Smaranda'}): 14,
#  frozenset({'Rogers Anna', 'Rumshisky Anna'}): 12,
#  frozenset({'Gimpel Kevin', 'Livescu Karen'}): 15,
#  frozenset({'Clark Peter', 'Dalvi Bhavana'}): 10,
#  frozenset({'Mille Simon', 'Wanner Leo'}): 28,
#  frozenset({'Wu Winston', 'Yarowsky David'}): 14,
#  frozenset({'Su Jinsong', 'Xiong Deyi'}): 13,
#  frozenset({'Huang Ting-Hao', 'Ku Lun-Wei'}): 10,
#  frozenset({'Ma Mingbo', 'Zheng Renjie'}): 14,
#  frozenset({'Huang Liang', 'Ma Mingbo'}): 23,
#  frozenset({'Huang Liang', 'Zheng Renjie'}): 14,
#  frozenset({'Xia Rui', 'Yu Jianfei'}): 11,
#  frozenset({'Chen Yidong', 'Shi Xiaodong'}): 17,
#  frozenset({'Li Sujian', 'Wang Houfeng'}): 17,
#  frozenset({'Goyal Pawan', 'Krishna Amrith'}): 15,
#  frozenset({'Liu Ting', 'Zhang Wei-Nan'}): 13,
#  frozenset({'Liu Ting', 'Zhang Yue'}): 11,
#  frozenset({'Potthast Martin', 'Stein Benno'}): 18,
#  frozenset({'Schwartz H. Andrew', 'Ungar Lyle'}): 16,
#  frozenset({'Thorne James', 'Vlachos Andreas'}): 15,
#  frozenset({'Christodoulopoulos Christos', 'Thorne James'}): 10,
#  frozenset({'Mittal Arpit', 'Thorne James'}): 10,
#  frozenset({'Christodoulopoulos Christos', 'Vlachos Andreas'}): 11,
#  frozenset({'Mittal Arpit', 'Vlachos Andreas'}): 11,
#  frozenset({'Christodoulopoulos Christos', 'Mittal Arpit'}): 13,
#  frozenset({'Grouin Cyril', 'Zweigenbaum Pierre'}): 22,
#  frozenset({'Lavergne Thomas', 'Zweigenbaum Pierre'}): 11,
#  frozenset({'Chen Chung-Chi', 'Huang Hen-Hsen'}): 10,
#  frozenset({'Chen Chung-Chi', 'Chen Hsin-Hsi'}): 10,
#  frozenset({'Chen Hsin-Hsi', 'Huang Hen-Hsen'}): 45,
#  frozenset({'Wang Rui', 'Zhao Hai'}): 14,
#  frozenset({'Gui Tao', 'Zhang Qi'}): 11,
#  frozenset({'Liu Ting', 'Zhang Yu'}): 11,
#  frozenset({'Gui Lin', 'Xu Ruifeng'}): 10,
#  frozenset({'Xu Ruifeng', 'Yang Min'}): 11,
#  frozenset({'Lin Jimmy', 'Tang Raphael'}): 14,
#  frozenset({'Gerz Daniela', "Vuli{\\'c} Ivan"}): 14,
#  frozenset({"Mrk{\\v{s}}i{\\'c} Nikola", "Vuli{\\'c} Ivan"}): 15,
#  frozenset({'Budzianowski Pawe{\\l}', 'Su Pei-Hao'}): 10,
#  frozenset({'Casanueva I{\\~n}igo', 'Su Pei-Hao'}): 11,
#  frozenset({"Mrk{\\v{s}}i{\\'c} Nikola", 'Su Pei-Hao'}): 20,
#  frozenset({'Su Pei-Hao', 'Wen Tsung-Hsien'}): 22,
#  frozenset({'Budzianowski Pawe{\\l}', 'Casanueva I{\\~n}igo'}): 14,
#  frozenset({'Casanueva I{\\~n}igo', 'Wen Tsung-Hsien'}): 11,
#  frozenset({"Mrk{\\v{s}}i{\\'c} Nikola", 'Wen Tsung-Hsien'}): 20,
#  frozenset({'Agirre Eneko', 'Lopez de Lacalle Oier'}): 15,
#  frozenset({'Agirre Eneko', 'Labaka Gorka'}): 19,
#  frozenset({'Gardner Matt', 'Singh Sameer'}): 21,
#  frozenset({'Dredze Mark', 'Van Durme Benjamin'}): 12,
#  frozenset({'Baldwin Timothy', 'Rahimi Afshin'}): 12,
#  frozenset({'Liu Yang', 'Luan Huanbo'}): 14,
#  frozenset({'Luan Huanbo', 'Sun Maosong'}): 17,
#  frozenset({'He Shizhu', 'Liu Kang'}): 18,
#  frozenset({'He Shizhu', 'Zhao Jun'}): 18,
#  frozenset({'Li Peifeng', 'Zhu Qiaoming'}): 16,
#  frozenset({'Xu Jinan', 'Zhang Yujie'}): 12,
#  frozenset({'Chen Yufeng', 'Zhang Yujie'}): 11,
#  frozenset({'Bach Nguyen', 'Jiang Yong'}): 10,
#  frozenset({'Jiang Yong', 'Wang Tao'}): 12,
#  frozenset({'Huang Zhongqiang', 'Jiang Yong'}): 11,
#  frozenset({'Huang Fei', 'Jiang Yong'}): 12,
#  frozenset({'Bach Nguyen', 'Wang Tao'}): 10,
#  frozenset({'Bach Nguyen', 'Huang Fei'}): 11,
#  frozenset({'Huang Zhongqiang', 'Wang Tao'}): 11,
#  frozenset({'Huang Fei', 'Wang Tao'}): 12,
#  frozenset({'Huang Fei', 'Huang Zhongqiang'}): 11,
#  frozenset({'Lan Man', 'Wu Yuanbin'}): 21,
#  frozenset({'Sun Xu', 'Yang Pengcheng'}): 15,
#  frozenset({'Feng Xiaocheng', 'Qin Bing'}): 12,
#  frozenset({'Liu Qun', 'Liu Yang'}): 27,
#  frozenset({'Ding Xiao', 'Liu Ting'}): 14,
#  frozenset({'Liu Ting', 'Qin Bing'}): 45,
#  frozenset({'Liu Qun', 'Xiong Deyi'}): 13,
#  frozenset({'Inui Kentaro', 'Matsubayashi Yuichiroh'}): 10,
#  frozenset({'Song Yangqiu', 'Zhang Hongming'}): 13,
#  frozenset({'Wu Hua', 'Xiao Xinyan'}): 13,
#  frozenset({'Inui Kentaro', 'Okazaki Naoaki'}): 35,
#  frozenset({'Hou Lei', 'Li Juanzi'}): 18,
#  frozenset({'Che Wanxiang', 'Wang Haifeng'}): 10,
#  frozenset({'Li Junhui', 'Zhou Guodong'}): 17,
#  frozenset({'Li Shoushan', 'Zhou Guodong'}): 30,
#  frozenset({'Zhang Min', 'Zhou Guodong'}): 19,
#  frozenset({'Teng Zhiyang', 'Zhang Yue'}): 10,
#  frozenset({'Zhang Jiajun', 'Zhou Yu'}): 16,
#  frozenset({'Zhou Yu', 'Zong Chengqing'}): 25,
#  frozenset({'Han Xianpei', 'Lin Hongyu'}): 18,
#  frozenset({'Lin Hongyu', 'Sun Le'}): 17,
#  frozenset({'Han Xianpei', 'Sun Le'}): 38,
#  frozenset({'Cui Lei', 'Wei Furu'}): 11,
#  frozenset({'Barzilay Regina', 'Jaakkola Tommi'}): 12,
#  frozenset({'Ritter Alan', 'Xu Wei'}): 19,
#  frozenset({'Huang Lifu', 'Ji Heng'}): 21,
#  frozenset({'Cer Daniel', 'Yang Yinfei'}): 12,
#  frozenset({'Fancellu Federico', 'Webber Bonnie'}): 10,
#  frozenset({'Inoue Naoya', 'Inui Kentaro'}): 21,
#  frozenset({'Mahata Debanjan', 'Shah Rajiv Ratn'}): 10,
#  frozenset({'Florian Radu', 'Roukos Salim'}): 14,
#  frozenset({'Cohn Trevor', 'Haffari Gholamreza'}): 15,
#  frozenset({'Liu Bing', 'Shu Lei'}): 11,
#  frozenset({'Shu Lei', 'Xu Hu'}): 11,
#  frozenset({'Korhonen Anna', 'McCarthy Diana'}): 12,
#  frozenset({'Klein Dan', 'Pauls Adam'}): 15,
#  frozenset({"P{\\'e}rez-Ortiz Juan Antonio",
#             "S{\\'a}nchez-Cartagena V{\\'\\i}ctor M."}): 11,
#  frozenset({"S{\\'a}nchez-Cartagena V{\\'\\i}ctor M.",
#             "S{\\'a}nchez-Mart{\\'\\i}nez Felipe"}): 10,
#  frozenset({'Espl{\\`a}-Gomis Miquel',
#             "S{\\'a}nchez-Mart{\\'\\i}nez Felipe"}): 12,
#  frozenset({'Cao Yixin', 'Li Juanzi'}): 12,
#  frozenset({'Cao Yixin', 'Liu Zhiyuan'}): 10,
#  frozenset({'Hou Lei', 'Liu Zhiyuan'}): 10,
#  frozenset({'Aharonov Ranit', 'Slonim Noam'}): 19,
#  frozenset({'Buechel Sven', 'Hahn Udo'}): 11,
#  frozenset({'Das Rajarshi', 'McCallum Andrew'}): 13,
#  frozenset({'Cheng Xueqi', 'Guo Jiafeng'}): 10,
#  frozenset({'Bojar Ond{\\v{r}}ej', 'Tamchyna Ale{\\v{s}}'}): 14,
#  frozenset({"Fern{\\'a}ndez-Gonz{\\'a}lez Daniel",
#             "G{\\'o}mez-Rodr{\\'\\i}guez Carlos"}): 11,
#  frozenset({'Knight Kevin', 'Zhang Boliang'}): 11,
#  frozenset({'Bar-Haim Roy', 'Slonim Noam'}): 12,
#  frozenset({'Han Wenjuan', 'Tu Kewei'}): 12,
#  frozenset({'Han Wenjuan', 'Jiang Yong'}): 10,
#  frozenset({'Lin Yi-Chung', 'Su Keh-Yih'}): 17,
#  frozenset({'Shen Xiaoyu', 'Su Hui'}): 10,
#  frozenset({'Wang William Yang', 'Wang Xin'}): 12,
#  frozenset({'Baldwin Timothy', 'Verspoor Karin'}): 10,
#  frozenset({'Taniguchi Motoki', 'Taniguchi Tomoki'}): 10,
#  frozenset({'Ohkuma Tomoko', 'Taniguchi Motoki'}): 13,
#  frozenset({'Ohkuma Tomoko', 'Taniguchi Tomoki'}): 15,
#  frozenset({'Nagata Masaaki', 'Suzuki Jun'}): 22,
#  frozenset({'Roth Dan', 'Rozovskaya Alla'}): 17,
#  frozenset({'Chang Shiyu', 'Yu Mo'}): 18,
#  frozenset({'Choi Yejin', 'Sap Maarten'}): 17,
#  frozenset({'Bhattacharyya Pushpak', 'Kulkarni Malhar'}): 15,
#  frozenset({'Idiart Marco', 'Villavicencio Aline'}): 21,
#  frozenset({'Glava{\\v{s}} Goran', 'Ponzetto Simone Paolo'}): 14,
#  frozenset({'Choudhury Monojit', 'Sitaram Sunayana'}): 11,
#  frozenset({'Biemann Chris', 'Panchenko Alexander'}): 25,
#  frozenset({'Bandyopadhyay Sivaji', 'Das Dipankar'}): 35,
#  frozenset({'Brunato Dominique', "Dell{'}Orletta Felice"}): 11,
#  frozenset({"Dell{'}Orletta Felice", 'Venturi Giulia'}): 25,
#  frozenset({'Carenini Giuseppe', 'Ng Raymond'}): 15,
#  frozenset({'Eckart de Castilho Richard', 'Gurevych Iryna'}): 12,
#  frozenset({'Mayhew Stephen', 'Roth Dan'}): 11,
#  frozenset({'Plank Barbara', 'S{\\o}gaard Anders'}): 23,
#  frozenset({'Bowman Samuel R.', 'Warstadt Alex'}): 10,
#  frozenset({'Ganguly Niloy', 'Mukherjee Animesh'}): 10,
#  frozenset({'Scarton Carolina', 'Specia Lucia'}): 28,
#  frozenset({'Huang Chu-Ren', 'Santus Enrico'}): 11,
#  frozenset({'Huang Chu-Ren', 'Lenci Alessandro'}): 10,
#  frozenset({'Manning Christopher D.', 'de Marneffe Marie-Catherine'}): 15,
#  frozenset({'Sun Weiwei', 'Wan Xiaojun'}): 22,
#  frozenset({'Hazarika Devamanyu', 'Poria Soujanya'}): 10,
#  frozenset({'Li Bin', 'Qu Weiguang'}): 11,
#  frozenset({'Zhu Jingbo', 'Zhu Muhua'}): 12,
#  frozenset({'Wang Huizhen', 'Zhu Jingbo'}): 11,
#  frozenset({'Pivovarova Lidia', 'Yangarber Roman'}): 17,
#  frozenset({'Alishahi Afra', 'Chrupa{\\l}a Grzegorz'}): 15,
#  frozenset({'Bowman Samuel R.', 'Liu Haokun'}): 11,
#  frozenset({'Lin Chen', 'Miller Timothy'}): 13,
#  frozenset({'Dligach Dmitriy', 'Lin Chen'}): 11,
#  frozenset({'Bethard Steven', 'Lin Chen'}): 12,
#  frozenset({'Lin Chen', 'Savova Guergana'}): 13,
#  frozenset({'Dligach Dmitriy', 'Miller Timothy'}): 17,
#  frozenset({'Bethard Steven', 'Miller Timothy'}): 14,
#  frozenset({'Miller Timothy', 'Savova Guergana'}): 20,
#  frozenset({'Bethard Steven', 'Dligach Dmitriy'}): 11,
#  frozenset({'Dligach Dmitriy', 'Savova Guergana'}): 14,
#  frozenset({'Bethard Steven', 'Savova Guergana'}): 16,
#  frozenset({'Kiesel Johannes', 'Stein Benno'}): 10,
#  frozenset({'Hong Yu', 'Yao Jianmin'}): 10,
#  frozenset({'Gao Yingbo', 'Ney Hermann'}): 10,
#  frozenset({'Mitkov Ruslan', 'Orasan Constantin'}): 12,
#  frozenset({'Zhou Guodong', 'Zhu Qiaoming'}): 31,
#  frozenset({'Basili Roberto', 'Croce Danilo'}): 25,
#  frozenset({'Dras Mark', 'Johnson Mark'}): 11,
#  frozenset({'Huang Xuanjing', 'Qiu Xipeng'}): 46,
#  frozenset({'Lin Junyang', 'Sun Xu'}): 12,
#  frozenset({'Lin Hongyu', 'Lu Yaojie'}): 11,
#  frozenset({'Han Xianpei', 'Lu Yaojie'}): 11,
#  frozenset({'Lu Yaojie', 'Sun Le'}): 11,
#  frozenset({'Levy Roger', 'Wilcox Ethan'}): 10,
#  frozenset({'Feng Xiaocheng', 'Liu Ting'}): 10,
#  frozenset({'Kloetzer Julien', 'Oh Jong-Hoon'}): 10,
#  frozenset({'Oh Jong-Hoon', 'Torisawa Kentaro'}): 20,
#  frozenset({'Kloetzer Julien', 'Torisawa Kentaro'}): 12,
#  frozenset({'Haddow Barry', 'Sennrich Rico'}): 17,
#  frozenset({'King Irwin', 'Lyu Michael'}): 10,
#  frozenset({'Andreas Jacob', 'Klein Dan'}): 14,
#  frozenset({'Song Linfeng', 'Zhang Yue'}): 16,
#  frozenset({'Fu Ruiji', 'Song Wei'}): 10,
#  frozenset({'Liu Ting', 'Song Wei'}): 11,
#  frozenset({'Liu Lizhen', 'Song Wei'}): 11,
#  frozenset({'Fu Ruiji', 'Liu Ting'}): 14,
#  frozenset({'Huang Xuanjing', 'Zhou Yaqian'}): 10,
#  frozenset({'Artetxe Mikel', 'Labaka Gorka'}): 16,
#  frozenset({'Agirre Eneko', 'Artetxe Mikel'}): 14,
#  frozenset({'Agirre Eneko', 'Soroa Aitor'}): 30,
#  frozenset({'Sap Maarten', 'Smith Noah A.'}): 10,
#  frozenset({'Smith Noah A.', 'Swayamdipta Swabha'}): 11,
#  frozenset({'Choi Yejin', 'Smith Noah A.'}): 14,
#  frozenset({'Koehn Philipp', 'Specia Lucia'}): 12,
#  frozenset({'Belinkov Yonatan', 'Durrani Nadir'}): 11,
#  frozenset({'Durrani Nadir', 'Koehn Philipp'}): 13,
#  frozenset({'Belinkov Yonatan', 'Sajjad Hassan'}): 14,
#  frozenset({'Haque Rejwanul', 'Way Andy'}): 22,
#  frozenset({'Dyer Chris', 'Ling Wang'}): 18,
#  frozenset({'Blunsom Phil', 'Dyer Chris'}): 20,
#  frozenset({'Byrne Bill', 'Saunders Danielle'}): 12,
#  frozenset({'Fraser Alexander', 'Schmid Helmut'}): 14,
#  frozenset({'Bhattacharyya Pushpak', 'Redkar Hanumant'}): 11,
#  frozenset({'Malmasi Shervin', 'Zampieri Marcos'}): 21,
#  frozenset({'Levy Omer', 'Zettlemoyer Luke'}): 10,
#  frozenset({'Burkett David', 'Klein Dan'}): 11,
#  frozenset({'Klein Dan', 'Liang Percy'}): 14,
#  frozenset({'Lewis Mike', 'Zettlemoyer Luke'}): 11,
#  frozenset({'Shaikh Samira', 'Strzalkowski Tomek'}): 19,
#  frozenset({'Abend Omri', 'Rappoport Ari'}): 24,
#  frozenset({'Adda-Decker Martine', 'Lamel Lori'}): 10,
#  frozenset({'Cotterell Ryan', 'Kirov Christo'}): 11,
#  frozenset({'Vu Ngoc Thang', 'Yu Xiang'}): 10,
#  frozenset({'Oraby Shereen', 'Walker Marilyn'}): 12,
#  frozenset({'Komatani Kazunori', 'Nakano Mikio'}): 11,
#  frozenset({"Barr{\\'o}n-Cede{\\~n}o Alberto", 'Da San Martino Giovanni'}): 16,
#  frozenset({"Barr{\\'o}n-Cede{\\~n}o Alberto", 'Nakov Preslav'}): 16,
#  frozenset({'Cohan Arman', 'Goharian Nazli'}): 14,
#  frozenset({'Lee Lung-Hao', 'Yu Liang-Chih'}): 12,
#  frozenset({'Sedoc Jo{\\~a}o', 'Ungar Lyle'}): 11,
#  frozenset({'Ahrens Kathleen', 'Huang Chu-Ren'}): 20,
#  frozenset({'Komiya Kanako', 'Shinnou Hiroyuki'}): 16,
#  frozenset({'Isahara Hitoshi', 'Kanzaki Kyoko'}): 27,
#  frozenset({'Isahara Hitoshi', 'Yamamoto Eiko'}): 12,
#  frozenset({'Song Yan', 'Xia Fei'}): 16,
#  frozenset({'Kawahara Daisuke', 'Kurohashi Sadao'}): 71,
#  frozenset({"Guti{\\'e}rrez Yoan", "Montoyo Andr{\\'e}s"}): 18,
#  frozenset({"Guti{\\'e}rrez Yoan", 'Mu{\\~n}oz Rafael'}): 14,
#  frozenset({"Montoyo Andr{\\'e}s", 'Mu{\\~n}oz Rafael'}): 13,
#  frozenset({'Ide Nancy', 'Suderman Keith'}): 19,
#  frozenset({'Ide Nancy', 'Pustejovsky James'}): 10,
#  frozenset({'Neubig Graham', 'Oda Yusuke'}): 13,
#  frozenset({'Helcl Jind{\\v{r}}ich', "Libovick{\\'y} Jind{\\v{r}}ich"}): 10,
#  frozenset({'Ramisch Carlos', 'Savary Agata'}): 11,
#  frozenset({'Bohnet Bernd', 'Mille Simon'}): 15,
#  frozenset({'Bohnet Bernd', 'Wanner Leo'}): 20,
#  frozenset({'Long Yunfei', 'Lu Qin'}): 10,
#  frozenset({'Bunt Harry', 'Petukhova Volha'}): 18,
#  frozenset({'Fung Pascale', 'Wu Chien-Sheng'}): 12,
#  frozenset({'Ishida Toru', 'Lin Donghui'}): 13,
#  frozenset({'Artstein Ron', 'Traum David'}): 18,
#  frozenset({'Matsubara Shigeki', 'Ohno Tomohiro'}): 11,
#  frozenset({'Georgila Kallirroi', 'Traum David'}): 13,
#  frozenset({'Leuski Anton', 'Traum David'}): 12,
#  frozenset({"Branco Ant{\\'o}nio", 'Silva Jo{\\~a}o'}): 24,
#  frozenset({"Dell{'}Orletta Felice", 'Montemagni Simonetta'}): 23,
#  frozenset({'Montemagni Simonetta', 'Venturi Giulia'}): 21,
#  frozenset({'Lenci Alessandro', 'Montemagni Simonetta'}): 14,
#  frozenset({"M{\\'\\i}rovsk{\\'y} Ji{\\v{r}}{\\'\\i}",
#             "Pol{\\'a}kov{\\'a} Lucie"}): 13,
#  frozenset({'Katsumata Satoru', 'Komachi Mamoru'}): 10,
#  frozenset({'Kar Sudipta', 'Solorio Thamar'}): 10,
#  frozenset({'Fukumoto Fumiyo', 'Suzuki Yoshimi'}): 23,
#  frozenset({'Boyd-Graber Jordan', 'Iyyer Mohit'}): 10,
#  frozenset({'Cui Lei', 'Zhou Ming'}): 17,
#  frozenset({'Bossy Robert', "N{\\'e}dellec Claire"}): 10,
#  frozenset({"Del{\\'e}ger Louise", 'Zweigenbaum Pierre'}): 10,
#  frozenset({'Ji Heng', 'Lu Di'}): 11,
#  frozenset({'Ananiadou Sophia', 'Thompson Paul'}): 16,
#  frozenset({'Hahn-Powell Gus', "Valenzuela-Esc{\\'a}rcega Marco A."}): 10,
#  frozenset({'Ding Chenchen', 'Utiyama Masao'}): 14,
#  frozenset({'Ding Chenchen', 'Sumita Eiichiro'}): 14,
#  frozenset({'Fokkens Antske', 'Vossen Piek'}): 14,
#  frozenset({'Ciobanu Alina Maria', 'Dinu Liviu P.'}): 17,
#  frozenset({'Erjavec Toma{\\v{z}}', "Ljube{\\v{s}}i{\\'c} Nikola"}): 10,
#  frozenset({'Choukri Khalid', 'Piperidis Stelios'}): 15,
#  frozenset({'Arranz Victoria', 'Choukri Khalid'}): 12,
#  frozenset({'Choukri Khalid', "Mapelli Val{\\'e}rie"}): 13,
#  frozenset({'Cieri Christopher', 'DiPersio Denise'}): 11,
#  frozenset({'Cieri Christopher', 'Strassel Stephanie'}): 11,
#  frozenset({'Cieri Christopher', 'Liberman Mark'}): 19,
#  frozenset({'Strassel Stephanie', 'Wright Jonathan'}): 10,
#  frozenset({"Lind{\\'e}n Krister", 'Silfverberg Miikka'}): 10,
#  frozenset({'Van den Bogaert Joachim', 'Vanallemeersch Tom'}): 10,
#  frozenset({'Cromieres Fabien', 'Kurohashi Sadao'}): 11,
#  frozenset({'Hathout Nabil', 'Namer Fiammetta'}): 10,
#  frozenset({'Habash Nizar', 'Zalmout Nasser'}): 14,
#  frozenset({'Cotterell Ryan', 'McCarthy Arya D.'}): 10,
#  frozenset({'Bies Ann', 'Mott Justin'}): 13,
#  frozenset({'Bies Ann', 'Strassel Stephanie'}): 13,
#  frozenset({'Haji{\\v{c}} Jan', 'Zeman Daniel'}): 10,
#  frozenset({'Camelin Nathalie', 'Est{\\`e}ve Yannick'}): 13,
#  frozenset({'Mayfield James', 'McNamee Paul'}): 12,
#  frozenset({"Branco Ant{\\'o}nio", 'Saedi Chakaveh'}): 11,
#  frozenset({'Maks Isa', 'Vossen Piek'}): 11,
#  frozenset({'Bhattacharyya Pushpak', 'Joshi Aditya'}): 24,
#  frozenset({'Bosco Cristina', 'Sanguinetti Manuela'}): 10,
#  frozenset({'Surdeanu Mihai', "Valenzuela-Esc{\\'a}rcega Marco A."}): 14,
#  frozenset({"Branco Ant{\\'o}nio", "Gomes Lu{\\'\\i}s"}): 11,
#  frozenset({'Rudinger Rachel', 'Van Durme Benjamin'}): 20,
#  frozenset({'Cuadros Montse', 'Rigau German'}): 13,
#  frozenset({'Marciniak Malgorzata', 'Mykowiecka Agnieszka'}): 12,
#  frozenset({'Krishnaswamy Nikhil', 'Pustejovsky James'}): 12,
#  frozenset({'Biemann Chris', 'Remus Steffen'}): 10,
#  frozenset({'Panchenko Alexander', 'Ustalov Dmitry'}): 11,
#  frozenset({'Biemann Chris', 'Ponzetto Simone Paolo'}): 11,
#  frozenset({'Panchenko Alexander', 'Ponzetto Simone Paolo'}): 11,
#  frozenset({'Kabashi Besim', 'Proisl Thomas'}): 11,
#  frozenset({'Portet Fran{\\c{c}}ois', 'Vacher Michel'}): 13,
#  frozenset({'Ng Vincent', 'Persing Isaac'}): 10,
#  frozenset({'Sharp Rebecca', 'Surdeanu Mihai'}): 12,
#  frozenset({"Cardon R{\\'e}mi", 'Grabar Natalia'}): 11,
#  frozenset({'Habash Nizar', 'Obeid Ossama'}): 11,
#  frozenset({'Dligach Dmitriy', 'Palmer Martha'}): 10,
#  frozenset({'Grabar Natalia', 'Hamon Thierry'}): 22,
#  frozenset({'Charlet Delphine', "Damnati G{\\'e}raldine"}): 14,
#  frozenset({'Ferret Olivier', 'Tannier Xavier'}): 12,
#  frozenset({"N{\\'e}v{\\'e}ol Aur{\\'e}lie", 'Tannier Xavier'}): 10,
#  frozenset({'Illouz Gabriel', 'Vilnat Anne'}): 11,
#  frozenset({"Delvaux V{\\'e}ronique", 'Huet Kathy'}): 10,
#  frozenset({"Delvaux V{\\'e}ronique", 'Piccaluga Myriam'}): 10,
#  frozenset({"Delvaux V{\\'e}ronique", 'Harmegnies Bernard'}): 10,
#  frozenset({'Huet Kathy', 'Piccaluga Myriam'}): 10,
#  frozenset({'Harmegnies Bernard', 'Huet Kathy'}): 10,
#  frozenset({'Harmegnies Bernard', 'Piccaluga Myriam'}): 10,
#  frozenset({'Nerima Luka', 'Wehrli Eric'}): 14,
#  frozenset({'Besacier Laurent', 'Lecouteux Benjamin'}): 13,
#  frozenset({'Nivre Joakim', 'de Lhoneux Miryam'}): 11,
#  frozenset({'Reiter Ehud', 'Sripada Somayajulu'}): 12,
#  frozenset({'Krahmer Emiel', 'Wubben Sander'}): 21,
#  frozenset({'Hagen Matthias', 'Stein Benno'}): 12,
#  frozenset({'Ji Heng', 'Knight Kevin'}): 16,
#  frozenset({'Chen Berlin', 'Liu Shih-Hung'}): 15,
#  frozenset({'Vela Mihaela', 'van Genabith Josef'}): 14,
#  frozenset({'Ekbal Asif', 'Saha Sriparna'}): 20,
#  frozenset({'Gao Jianfeng', 'Li Xiujun'}): 12,
#  frozenset({'Bilu Yonatan', 'Slonim Noam'}): 14,
#  frozenset({'Ge Tao', 'Zhou Ming'}): 11,
#  frozenset({'Bi Wei', 'Liu Xiaojiang'}): 13,
#  frozenset({'Che Wanxiang', 'Qin Bing'}): 11,
#  frozenset({'Gurevych Iryna', 'Habernal Ivan'}): 15,
#  frozenset({'Qin Bing', 'Tang Duyu'}): 12,
#  frozenset({'Liu Ting', 'Tang Duyu'}): 12,
#  frozenset({'Bhattacharyya Pushpak', 'Gupta Deepak'}): 10,
#  frozenset({'Mare{\\v{c}}ek David', 'Rosa Rudolf'}): 11,
#  frozenset({'Bernardi Raffaella', 'Pezzelle Sandro'}): 13,
#  frozenset({'Carin Lawrence', 'Wang Guoyin'}): 10,
#  frozenset({'Poliak Adam', 'Van Durme Benjamin'}): 13,
#  frozenset({'Beigman Klebanov Beata', 'Flor Michael'}): 13,
#  frozenset({'Khayrallah Huda', 'Koehn Philipp'}): 12,
#  frozenset({'Nagata Masaaki', 'Nishino Masaaki'}): 10,
#  frozenset({'Zhao Tiejun', 'Zhu Conghui'}): 12,
#  frozenset({"G{\\'o}mez-Rodr{\\'\\i}guez Carlos", 'Vilares David'}): 20,
#  frozenset({'Choi Yejin', 'Rashkin Hannah'}): 11,
#  frozenset({'Chang Shiyu', 'Guo Xiaoxiao'}): 11,
#  frozenset({'Johannsen Anders', "Mart{\\'\\i}nez Alonso H{\\'e}ctor"}): 10,
#  frozenset({'Carin Lawrence', 'Shen Dinghan'}): 14,
#  frozenset({'Liu Xiaojiang', 'Shi Shuming'}): 10,
#  frozenset({'Miura Yasuhide', 'Ohkuma Tomoko'}): 19,
#  frozenset({'Kim Yunsu', 'Ney Hermann'}): 14,
#  frozenset({'Forcada Mikel L.', "S{\\'a}nchez-Mart{\\'\\i}nez Felipe"}): 18,
#  frozenset({'Forcada Mikel L.', "P{\\'e}rez-Ortiz Juan Antonio"}): 10,
#  frozenset({'Espl{\\`a}-Gomis Miquel', 'Forcada Mikel L.'}): 10,
#  frozenset({'Abend Omri', 'Hershcovich Daniel'}): 12,
#  frozenset({'Abzianidze Lasha', 'Bos Johan'}): 15,
#  frozenset({'Eger Steffen', 'Gurevych Iryna'}): 12,
#  frozenset({'Demberg Vera', 'Sayeed Asad'}): 16,
#  frozenset({'Bhattacharyya Pushpak', 'Dabre Raj'}): 11,
#  frozenset({'Chen Wenliang', 'Zhang Min'}): 16,
#  frozenset({'Chen Qingcai', 'Wang Xiaolong'}): 10,
#  frozenset({'Habash Nizar', 'Tomeh Nadi'}): 10,
#  frozenset({'Banea Carmen', 'Mihalcea Rada'}): 21,
#  frozenset({'Sumita Eiichiro', 'Tamura Akihiro'}): 10,
#  frozenset({'Napoles Courtney', 'Tetreault Joel'}): 10,
#  frozenset({'Blache Philippe', "Rauzy St{\\'e}phane"}): 14,
#  frozenset({'Hazem Amir', 'Morin Emmanuel'}): 15,
#  frozenset({'Makhoul John', 'Schwartz Richard'}): 24,
#  frozenset({'Chamberlain Jon', 'Kruschwitz Udo'}): 10,
#  frozenset({'Kruschwitz Udo', 'Poesio Massimo'}): 16,
#  frozenset({'Korhonen Anna', 'Poibeau Thierry'}): 11,
#  frozenset({'Belinkov Yonatan', 'Glass James'}): 11,
#  frozenset({'Zhang Meishan', 'Zhang Yue'}): 16,
#  frozenset({'Li Sheng', 'Zhao Tiejun'}): 14,
#  frozenset({'Rapp Reinhard', 'Zweigenbaum Pierre'}): 11,
#  frozenset({'Rapp Reinhard', 'Sharoff Serge'}): 13,
#  frozenset({'Sharoff Serge', 'Zweigenbaum Pierre'}): 10,
#  frozenset({'Cahill Aoife', 'Madnani Nitin'}): 15,
#  frozenset({'Hahn-Powell Gus', 'Surdeanu Mihai'}): 10,
#  frozenset({'Liu Ting', 'Wang Haifeng'}): 20,
#  frozenset({'Che Wanxiang', 'Liu Yijia'}): 13,
#  frozenset({'Liu Ting', 'Liu Yijia'}): 11,
#  frozenset({'Eskenazi Maxine', 'Zhao Tiancheng'}): 13,
#  frozenset({'Gurevych Iryna', 'Meyer Christian M.'}): 15,
#  frozenset({'Hoang Hieu', 'Koehn Philipp'}): 18,
#  frozenset({'Li Peifeng', 'Zhou Guodong'}): 13,
#  frozenset({'Fern Xiaoli', 'Tadepalli Prasad'}): 10,
#  frozenset({'Hovy Eduard', 'Ma Xuezhe'}): 13,
#  frozenset({'Byrne Bill', 'Stahlberg Felix'}): 18,
#  frozenset({'Andrews Nicholas', 'Dredze Mark'}): 10,
#  frozenset({'Bhattacharyya Pushpak', 'Mishra Abhijit'}): 15,
#  frozenset({"Freitas Andr{\\'e}", 'Handschuh Siegfried'}): 17,
#  frozenset({'Schlangen David', 'Zarrie{\\ss} Sina'}): 15,
#  frozenset({'Dagan Ido', 'Gurevych Iryna'}): 10,
#  frozenset({"Fu{\\v{c}}{\\'\\i}kov{\\'a} Eva",
#             "Ure{\\v{s}}ov{\\'a} Zde{\\v{n}}ka"}): 10,
#  frozenset({'Haji{\\v{c}} Jan', "Ure{\\v{s}}ov{\\'a} Zde{\\v{n}}ka"}): 17,
#  frozenset({'Song Zhiyi', 'Strassel Stephanie'}): 15,
#  frozenset({'Bies Ann', 'Kulick Seth'}): 25,
#  frozenset({'Pal Santanu', 'van Genabith Josef'}): 14,
#  frozenset({'Zampieri Marcos', 'van Genabith Josef'}): 13,
#  frozenset({'Sumita Eiichiro', 'Wang Xiaolin'}): 12,
#  frozenset({'Eshghi Arash', 'Lemon Oliver'}): 10,
#  frozenset({'Neves Mariana', 'Verspoor Karin'}): 10,
#  frozenset({'Casacuberta Francisco', "Sanchis-Trilles Germ{\\'a}n"}): 13,
#  frozenset({'Naskar Sudip Kumar', 'Pal Santanu'}): 15,
#  frozenset({'Naskar Sudip Kumar', 'van Genabith Josef'}): 14,
#  frozenset({'Byrne Bill', 'de Gispert Adri{\\`a}'}): 14,
#  frozenset({'Fraser Alexander', 'Huck Matthias'}): 12,
#  frozenset({'Ha Thanh-Le', 'Niehues Jan'}): 15,
#  frozenset({'Mitamura Teruko', 'Nyberg Eric'}): 23,
#  frozenset({'Attia Mohammed', 'Samih Younes'}): 13,
#  frozenset({'El-Hajj Wassim', 'Hajj Hazem'}): 10,
#  frozenset({'Habash Nizar', 'Rambow Owen'}): 38,
#  frozenset({'Inui Kentaro', 'Reisert Paul'}): 11,
#  frozenset({'Bos Johan', 'Evang Kilian'}): 10,
#  frozenset({'Real Livy', 'de Paiva Valeria'}): 10,
#  frozenset({'Hahn Udo', 'Hellrich Johannes'}): 11,
#  frozenset({"Daum{\\'e} III Hal", 'Rao Sudha'}): 10,
#  frozenset({'Karan Mladen', '{\\v{S}}najder Jan'}): 10,
#  frozenset({'Riccardi Giuseppe', 'Stepanov Evgeny'}): 13,
#  frozenset({'Allauzen Cyril', 'Riley Michael'}): 11,
#  frozenset({'Prasad Rashmi', 'Webber Bonnie'}): 14,
#  frozenset({'Lee Alan', 'Prasad Rashmi'}): 10,
#  frozenset({'Akhtar Md Shad', 'Ekbal Asif'}): 14,
#  frozenset({'Akhtar Md Shad', 'Bhattacharyya Pushpak'}): 12,
#  frozenset({'Callison-Burch Chris', 'Cocos Anne'}): 11,
#  frozenset({'Apidianaki Marianna', 'Callison-Burch Chris'}): 12,
#  frozenset({'Martin Maite', "Ure{\\~n}a-L{\\'o}pez L. Alfonso"}): 10,
#  frozenset({"Hoste V{\\'e}ronique", 'Lefever Els'}): 22,
#  frozenset({'Bontcheva Kalina', 'Maynard Diana'}): 13,
#  frozenset({'Bontcheva Kalina', 'Derczynski Leon'}): 12,
#  frozenset({'Basile Pierpaolo', 'Semeraro Giovanni'}): 11,
#  frozenset({'Krahmer Emiel', 'van den Bosch Antal'}): 11,
#  frozenset({'Maharjan Suraj', 'Solorio Thamar'}): 14,
#  frozenset({'Montes Manuel', 'Solorio Thamar'}): 10,
#  frozenset({"Barr{\\'o}n-Cede{\\~n}o Alberto",
#             "M{\\`a}rquez Llu{\\'\\i}s"}): 13,
#  frozenset({"M{\\`a}rquez Llu{\\'\\i}s", 'Nakov Preslav'}): 27,
#  frozenset({'Gildea Daniel', 'Song Linfeng'}): 12,
#  frozenset({'Cardie Claire', 'Choi Yejin'}): 10,
#  frozenset({'Niehues Jan', 'Waibel Alex'}): 50,
#  frozenset({'Carenini Giuseppe', 'Joty Shafiq'}): 10,
#  frozenset({'Carenini Giuseppe', 'Murray Gabriel'}): 10,
#  frozenset({'Chang Jason', 'Chen Jhih-Jie'}): 10,
#  frozenset({'Duh Kevin', 'Van Durme Benjamin'}): 12,
#  frozenset({'Dahlmeier Daniel', 'Ng Hwee Tou'}): 17,
#  frozenset({'Cambria Erik', 'Poria Soujanya'}): 17,
#  frozenset({'Gurevych Iryna', 'Stab Christian'}): 14,
#  ...}

# %%
def find_clusters( tuples ):
    # clusterlist contains at each position either a set
    # representing an actual cluster, or an int referring
    # to another cluster that has eaten this one here.
    # the cluster id is its position within this list
    clusterlist=[]
    # clustermap maps an element to the id of the containing
    # cluster within clusterlist
    clustermap = {}

    # here we find the current cluster id for elem, by following the
    # chain within clusterlist, and replace that entire chain
    # with the new cluster id n.   We return the old cluster id.
    def set_cluster_id( elem, n ):
        if elem not in clustermap:
            return None
        k = clustermap[elem]
        # clusters may be replaced by references to other clusters,
        # we follow that chain
        while k < n and isinstance( clusterlist[k], int ):
            k1 = clusterlist[k]
            # this is optional, we make the chain shorter
            # by making this entry point directly to the current cluster
            clusterlist[k] = n
            k = k1
        return k

    for t in tuples:
        # for each tuple we create a new cluster
        thiscluster = set(t)
        n = len( clusterlist ) # the id of thiscluster
        for x in t:
            # we absorb existing clusters into the new one
            # if there is overlap
            k = set_cluster_id(x, n)
            if k is not None and k != n:
                thiscluster.update( clusterlist[k] )
                # we replace the existing cluster
                # with a reference to the new one
                clusterlist[k] = n 
            clustermap[x] = n
        clusterlist.append(thiscluster)

    return [ tuple(x) for x in clusterlist if isinstance( x, set ) ]

# %%
clusters = find_clusters(L2)

# %%
clusters
# Out:
# [('Rashid Ahmad', 'Rezagholizadeh Mehdi'),
#  ('Gwinnup Jeremy', 'Erdmann Grant', 'Anderson Tim'),
#  ('Wang Mingxuan', 'Li Lei', 'Zhou Hao'),
#  ('Yang Hao',
#   'Guo Jiaxin',
#   'Wang Minghan',
#   'Lei Lizhi',
#   'Qin Ying',
#   'Shang Hengchao',
#   'Wei Daimeng'),
#  ('Grundkiewicz Roman',
#   'Junczys-Dowmunt Marcin',
#   'Heafield Kenneth',
#   'Bogoychev Nikolay'),
#  ('Senellart Jean', 'Crego Josep'),
#  ('Fujita Atsushi', 'Marie Benjamin'),
#  ('Nagoudi El Moatez Billah', 'Abdul-Mageed Muhammad'),
#  ('Lichouri Mohamed', 'Abbas Mourad'),
#  ('Schulte im Walde Sabine', 'Schlechtweg Dominik'),
#  ('Caines Andrew', 'Buttery Paula'),
#  ('Kahane Sylvain', 'Gerdes Kim'),
#  ('Foster Jennifer', 'Wagner Joachim'),
#  ('Socher Richard', 'Xiong Caiming'),
#  ('Opitz Juri', 'Frank Anette'),
#  ('Bjerva Johannes', 'Augenstein Isabelle'),
#  ('Koller Alexander', 'Groschwitz Jonas'),
#  ('Illina Irina', 'Fohr Dominique'),
#  ('Gonzalez-Hernandez Graciela', 'Weissenbacher Davy'),
#  ('Chakravarthi Bharathi Raja', 'McCrae John P.', 'Priyadharshini Ruba'),
#  ('Liu Zhengyuan', 'Chen Nancy'),
#  ('Zhang Xuejie', 'Wang Jin'),
#  ('Ilvovsky Dmitry', 'Galitsky Boris'),
#  ('Kamigaito Hidetaka', 'Okumura Manabu', 'Takamura Hiroya'),
#  ('Yeung Chak Yan', 'Lee John'),
#  ('Gravier Guillaume', "S{\\'e}billot Pascale"),
#  ('Osenova Petya', 'Simov Kiril'),
#  ('Popescu Octavian', 'Vo Ngoc Phuoc An'),
#  ('Villata Serena', 'Cabrio Elena'),
#  ('Liu Fei', 'Lebanoff Logan'),
#  ('Chatzikyriakidis Stergios', 'Bernardy Jean-Philippe'),
#  ('Demeester Thomas', 'Develder Chris'),
#  ('Malakasiotis Prodromos', 'Androutsopoulos Ion', 'Pavlopoulos John'),
#  ('Liu Jingjing', 'Cheng Yu', 'Gan Zhe'),
#  ('Zhu Chenguang', 'Zeng Michael'),
#  ('Jiang Haoming', 'Zhao Tuo'),
#  ('Sabharwal Ashish', 'Khot Tushar'),
#  ('Xia Congying', 'Yu Philip'),
#  ('Zhao Dongyan', 'Yan Rui', 'Feng Yansong'),
#  ('Suleman Kaheer', 'Trischler Adam'),
#  ('Lin Chenghua', 'Chen Guanyi'),
#  ('Weston Jason', 'Dinan Emily'),
#  ('Parikh Devi', 'Batra Dhruv'),
#  ('Xu Weiran', 'Yan Yuanmeng', 'He Keqing'),
#  ('Black Alan W', 'Prabhumoye Shrimai'),
#  ('Chang Kai-Wei', 'Ahmad Wasi', 'Zhao Jieyu'),
#  ('Hu Zhiting', 'Xing Eric'),
#  ('Dhingra Bhuwan', 'Cohen William'),
#  ('Yu Kai', 'Chen Lu', 'Zhu Su'),
#  ('Chen Jiajun', 'Huang Shujian', 'Dai Xinyu'),
#  ('Chiticariu Laura', 'Li Yunyao'),
#  ('Liu Tingwen', 'Yu Bowen'),
#  ('Gong Hongyu', 'Bhat Suma'),
#  ('Bekki Daisuke', 'Yanaka Hitomi', 'Mineshima Koji'),
#  ('Paggio Patrizia', 'Navarretta Costanza'),
#  ('Kijak Ewa', 'Claveau Vincent'),
#  ('Pino Juan', 'Wang Changhan'),
#  ('Guillaume Bruno', 'Perrier Guy'),
#  ('Arcan Mihael', 'Buitelaar Paul'),
#  ('Litvak Marina', 'Vanetik Natalia'),
#  ('El-Haj Mahmoud', 'Rayson Paul'),
#  ('Xu Kun', 'Yu Dian', 'Yu Dong'),
#  ('Huang Yongfeng', 'Xie Xing', 'Wu Fangzhao', 'Wu Chuhan', 'Qi Tao'),
#  ('Choubey Prafulla Kumar', 'Huang Ruihong'),
#  ('Staiano Jacopo', 'Scialom Thomas'),
#  ('Zhang Wenxuan', 'Bing Lidong', 'Lam Wai'),
#  ('Lin Hongfei', 'Yang Liang'),
#  ('Shutova Ekaterina', 'Rei Marek', 'Yannakoudakis Helen'),
#  ('Yu Zhou', 'Shi Weiyan'),
#  ('Matsuo Yutaka', 'Marrese-Taylor Edison'),
#  ('Tan Xu', 'Liu Tie-Yan', 'Qin Tao', 'Wu Lijun'),
#  ('Schuler William', 'Jin Lifeng'),
#  ('He Yulan', 'Zhou Deyu'),
#  ('Liu Qian', 'Lou Jian-Guang'),
#  ('Kim Young-Bum', 'Sarikaya Ruhi'),
#  ('Zhao Wayne Xin', 'Wen Ji-Rong'),
#  ('Zhu Xiaoyan', 'Takanobu Ryuichi', 'Huang Minlie'),
#  ('Wang Chengyu', 'He Xiaofeng'),
#  ('Sun Changlong', 'Liu Xiaozhong'),
#  ('Chakrabarty Tuhin', 'Ghosh Debanjan', 'Muresan Smaranda'),
#  ('Tandon Niket', 'Clark Peter', 'Dalvi Bhavana'),
#  ('Wu Winston', 'Yarowsky David'),
#  ('Xia Rui', 'Yu Jianfei'),
#  ('Chen Yidong', 'Shi Xiaodong'),
#  ('Goyal Pawan', 'Krishna Amrith'),
#  ('Mittal Arpit',
#   'Vlachos Andreas',
#   'Thorne James',
#   'Christodoulopoulos Christos'),
#  ('Xin Ji', 'Tang Raphael', 'Lin Jimmy'),
#  ('Gardner Matt', 'Dasigi Pradeep', 'Singh Sameer'),
#  ('Wu Yuanbin', 'Lan Man'),
#  ('Song Yangqiu', 'Zhang Hongming'),
#  ('Xu Wei', 'Ritter Alan'),
#  ('Yang Yinfei', 'Cer Daniel'),
#  ('Mahata Debanjan', 'Shah Rajiv Ratn', 'Sawhney Ramit'),
#  ('Roukos Salim', 'Florian Radu'),
#  ('Guo Jiafeng', 'Cheng Xueqi'),
#  ('Su Hui', 'Shen Xiaoyu'),
#  ('Chen Wenhu', 'Wang Xin', 'Wang William Yang', 'Xiong Wenhan'),
#  ('Qu Weiguang', 'Li Bin', 'Zhou Junsheng'),
#  ('Zhu Jingbo', 'Zhu Muhua', 'Li Bei', 'Wang Huizhen', 'Xiao Tong'),
#  ('Chrupa{\\l}a Grzegorz', 'Alishahi Afra'),
#  ('Liu Haokun', 'Warstadt Alex', 'Bowman Samuel R.'),
#  ('Mitkov Ruslan', 'Orasan Constantin'),
#  ('Han Xianpei', 'Lu Yaojie', 'Lin Hongyu', 'Sun Le'),
#  ('Levy Roger', 'Wilcox Ethan'),
#  ('King Irwin', 'Lyu Michael'),
#  ('Liu Pengfei',
#   'Gui Tao',
#   'Zhou Yaqian',
#   'Qiu Xipeng',
#   'Yan Hang',
#   'Wei Zhongyu',
#   'Zhang Qi',
#   'Huang Xuanjing'),
#  ('Adda-Decker Martine', 'Lamel Lori'),
#  ('Vu Ngoc Thang', 'Yu Xiang'),
#  ('Goharian Nazli', 'Cohan Arman'),
#  ('Helcl Jind{\\v{r}}ich', "Libovick{\\'y} Jind{\\v{r}}ich"),
#  ('Mille Simon', 'Wanner Leo', 'Bohnet Bernd'),
#  ('Bunt Harry', 'Petukhova Volha'),
#  ('Wu Chien-Sheng',
#   'Liu Zihan',
#   'Xu Peng',
#   'Lin Zhaojiang',
#   'Madotto Andrea',
#   'Winata Genta Indra',
#   'Fung Pascale'),
#  ("M{\\'\\i}rovsk{\\'y} Ji{\\v{r}}{\\'\\i}", "Pol{\\'a}kov{\\'a} Lucie"),
#  ('Suzuki Yoshimi', 'Fukumoto Fumiyo'),
#  ('Bossy Robert', "N{\\'e}dellec Claire"),
#  ('Ciobanu Alina Maria', 'Dinu Liviu P.'),
#  ('Vanallemeersch Tom', 'Van den Bogaert Joachim'),
#  ('Namer Fiammetta', 'Hathout Nabil'),
#  ('Camelin Nathalie', 'Est{\\`e}ve Yannick'),
#  ('McNamee Paul', 'Mayfield James'),
#  ('Sanguinetti Manuela', 'Bosco Cristina'),
#  ('Marciniak Malgorzata', 'Mykowiecka Agnieszka'),
#  ('Proisl Thomas', 'Kabashi Besim'),
#  ('Vacher Michel', 'Portet Fran{\\c{c}}ois'),
#  ('Grabar Natalia', 'Hamon Thierry', "Cardon R{\\'e}mi"),
#  ('Charlet Delphine', "Damnati G{\\'e}raldine"),
#  ('Harmegnies Bernard',
#   'Piccaluga Myriam',
#   'Huet Kathy',
#   "Delvaux V{\\'e}ronique"),
#  ('Sripada Somayajulu', 'Reiter Ehud'),
#  ('Aharonov Ranit', 'Bilu Yonatan', 'Bar-Haim Roy', 'Slonim Noam'),
#  ('Pezzelle Sandro', 'Bernardi Raffaella'),
#  ('Flor Michael', 'Beigman Klebanov Beata'),
#  ('Anderson Mark',
#   "G{\\'o}mez-Rodr{\\'\\i}guez Carlos",
#   'Vilares David',
#   "Fern{\\'a}ndez-Gonz{\\'a}lez Daniel"),
#  ('Yu Mo', 'Guo Xiaoxiao', 'Chang Shiyu'),
#  ('Carin Lawrence', 'Shen Dinghan', 'Wang Guoyin'),
#  ('Miura Yasuhide', 'Ohkuma Tomoko', 'Taniguchi Tomoki', 'Taniguchi Motoki'),
#  ("S{\\'a}nchez-Cartagena V{\\'\\i}ctor M.",
#   "P{\\'e}rez-Ortiz Juan Antonio",
#   "S{\\'a}nchez-Mart{\\'\\i}nez Felipe",
#   'Forcada Mikel L.',
#   'Espl{\\`a}-Gomis Miquel'),
#  ('Sayeed Asad', 'Demberg Vera'),
#  ('Chen Qingcai', 'Wang Xiaolong'),
#  ('Surdeanu Mihai',
#   'Hahn-Powell Gus',
#   "Valenzuela-Esc{\\'a}rcega Marco A.",
#   'Sharp Rebecca'),
#  ('Zhao Tiancheng', 'Mehri Shikib', 'Eskenazi Maxine'),
#  ('Fern Xiaoli', 'Tadepalli Prasad'),
#  ('Hajj Hazem', 'El-Hajj Wassim'),
#  ('Evang Kilian', 'Abzianidze Lasha', 'van Noord Rik', 'Bos Johan'),
#  ('Real Livy', 'de Paiva Valeria'),
#  ('Stepanov Evgeny', 'Riccardi Giuseppe'),
#  ('Riley Michael', 'Allauzen Cyril'),
#  ("Ure{\\~n}a-L{\\'o}pez L. Alfonso", 'Martin Maite'),
#  ('Semeraro Giovanni', 'Basile Pierpaolo'),
#  ('Chang Jason', 'Chen Jhih-Jie'),
#  ('Dahlmeier Daniel', 'Ng Hwee Tou'),
#  ('Auli Michael', 'Grangier David'),
#  ('Kiritchenko Svetlana', 'Mohammad Saif'),
#  ('Nguyen Dat Quoc', 'Nguyen Dai Quoc'),
#  ('Oepen Stephan', 'Velldal Erik', '{\\O}vrelid Lilja', 'Flickinger Dan'),
#  ('Lefever Els', "Hoste V{\\'e}ronique", "De Clercq Orph{\\'e}e"),
#  ("Daum{\\'e} III Hal",
#   'Resnik Philip',
#   'Iyyer Mohit',
#   'Rao Sudha',
#   'Boyd-Graber Jordan'),
#  ('Komiya Kanako', 'Shinnou Hiroyuki', 'Sasaki Minoru'),
#  ('Ziai Ramon', 'Meurers Detmar'),
#  ('Al-Khatib Khalid',
#   'Stein Benno',
#   'Kiesel Johannes',
#   'Al Khatib Khalid',
#   'Potthast Martin',
#   'Hagen Matthias',
#   'Wachsmuth Henning'),
#  ("Herv{\\'a}s Raquel", "Gerv{\\'a}s Pablo"),
#  ('Prokopidis Prokopis', 'Papavassiliou Vassilis'),
#  ("Ljube{\\v{s}}i{\\'c} Nikola", 'Fi{\\v{s}}er Darja', 'Erjavec Toma{\\v{z}}'),
#  ('Volodina Elena', "Pil{\\'a}n Ildik{\\'o}"),
#  ('Kotani Katsunori', 'Yoshimi Takehiko'),
#  ('Wu Shih-Hung', 'Chen Liang-Pu'),
#  ('Kruschwitz Udo',
#   'Uryupina Olga',
#   'Chamberlain Jon',
#   'Yu Juntao',
#   'Poesio Massimo'),
#  ('Barbieri Francesco',
#   'Saggion Horacio',
#   'Espinosa-Anke Luis',
#   'Ronzano Francesco'),
#  ('Boytcheva Svetla', 'Angelova Galia', 'Nikolova Ivelina'),
#  ('Pinkal Manfred', 'Thater Stefan'),
#  ('Villavicencio Aline',
#   'Idiart Marco',
#   'Ramisch Carlos',
#   'Wilkens Rodrigo',
#   'Savary Agata'),
#  ('Davis Brian', 'Handschuh Siegfried', "Freitas Andr{\\'e}"),
#  ('Ishida Toru', 'Lin Donghui', 'Murakami Yohei'),
#  ('Hagen Kristin', 'Johannessen Janne Bondi'),
#  ('Bechet Frederic', 'Favre Benoit'),
#  ('Ungar Lyle',
#   'Schwartz H. Andrew',
#   'Sedoc Jo{\\~a}o',
#   'Preo{\\c{t}}iuc-Pietro Daniel'),
#  ('Iosif Elias', 'Potamianos Alexandros'),
#  ('Maziarz Marek', 'Piasecki Maciej'),
#  ('Utsuro Takehito', 'Yamamoto Mikio'),
#  ('Walker Marilyn', 'Anand Pranav', 'Oraby Shereen'),
#  ('Huang Liang', 'Zheng Renjie', 'Ma Mingbo', 'Zhao Kai'),
#  ('Wan Xiaojun', 'Xiao Jianguo', 'Sun Weiwei'),
#  ('Lapata Mirella',
#   'Gardent Claire',
#   'Shimorina Anastasia',
#   'Cohen Shay B.',
#   'Perez-Beltrachini Laura',
#   'Narayan Shashi'),
#  ("Bel N{\\'u}ria", 'Marimon Montserrat'),
#  ('Boldrini Ester', "Mart{\\'\\i}nez-Barco Patricio"),
#  ('Banjade Rajendra', 'Rus Vasile'),
#  ('Das Rajarshi',
#   'Riedel Sebastian',
#   'Verga Patrick',
#   'Stenetorp Pontus',
#   'McCallum Andrew'),
#  ('Lafourcade Mathieu', 'Joubert Alain'),
#  ('Lu Zhengdong', 'Li Hang'),
#  ('Jaakkola Tommi', 'Barzilay Regina', 'Zhang Yuan', 'Lei Tao'),
#  ('Chen Weizhu',
#   'Celikyilmaz Asli',
#   'Zhang Yizhe',
#   'Liu Xiaodong',
#   'Peng Baolin',
#   'Deng Li',
#   'Xiang Bing',
#   'Brockett Chris',
#   'He Pengcheng',
#   'Wu Youzheng',
#   'Gao Jianfeng',
#   'Li Xiujun',
#   'He Xiaodong',
#   'Nallapati Ramesh',
#   'Zhou Bowen',
#   'Dolan Bill',
#   'Galley Michel'),
#  ('Liu Shih-Hung',
#   'Chen Kuan-Yu',
#   'Lo Tien-Hong',
#   'Wang Hsin-Min',
#   'Hung Hsiao-Tsung',
#   'Chen Berlin'),
#  ('Sinha Manjira', 'Dasgupta Tirthankar', 'Basu Anupam'),
#  ('Kallmeyer Laura', 'Maier Wolfgang'),
#  ('Jokinen Kristiina', 'Wilcock Graham'),
#  ('Henrich Verena', 'Hinrichs Erhard'),
#  ('Prasad Rashmi',
#   'Webber Bonnie',
#   'Fancellu Federico',
#   'Lee Alan',
#   'Joshi Aravind'),
#  ('Vandeghinste Vincent', 'Schuurman Ineke'),
#  ('S{\\o}gaard Anders',
#   'Fornaciari Tommaso',
#   "Mart{\\'\\i}nez Alonso H{\\'e}ctor",
#   'Johannsen Anders',
#   'Barrett Maria',
#   'Plank Barbara',
#   'Hovy Dirk'),
#  ('Lazaridou Angeliki', 'Baroni Marco'),
#  ('Ng Vincent', 'Persing Isaac', 'Chen Chen'),
#  ('Afantenos Stergos', 'Asher Nicholas'),
#  ('Mielke Sabrina J.',
#   'Jauhiainen Heidi',
#   'Kuhn Roland',
#   'Luo Weihua',
#   'McCarthy Arya D.',
#   'Kondrak Grzegorz',
#   'Hulden Mans',
#   "Lind{\\'e}n Krister",
#   'Foster George',
#   'Cherry Colin',
#   'Silfverberg Miikka',
#   'Hauer Bradley',
#   'Jauhiainen Tommi',
#   'Meister Clara',
#   'Chen Boxing',
#   'Eisner Jason',
#   'Nicolai Garrett',
#   'Vieira Tim',
#   'Kirov Christo',
#   'Cotterell Ryan',
#   'Pimentel Tiago',
#   'Williams Adina',
#   'Vylomova Ekaterina'),
#  ('Saratxaga Ibon', 'Navas Eva'),
#  ('Strassel Stephanie',
#   'Song Zhiyi',
#   'Bies Ann',
#   'Wright Jonathan',
#   'Liberman Mark',
#   'Maamouri Mohamed',
#   'Kulick Seth',
#   'Mott Justin',
#   'DiPersio Denise',
#   'Cieri Christopher'),
#  ('Ganguly Niloy',
#   'Choudhury Monojit',
#   'Mukherjee Animesh',
#   'Bali Kalika',
#   'Sitaram Sunayana'),
#  ('Kaji Nobuhiro', 'Yoshinaga Naoki', 'Kitsuregawa Masaru', 'Toyoda Masashi'),
#  ("Blanchon Herv{\\'e}", 'Lecouteux Benjamin', 'Besacier Laurent'),
#  ('Hazem Amir', 'Morin Emmanuel', "Daille B{\\'e}atrice"),
#  ('Seretan Violeta', 'Nerima Luka', 'Wehrli Eric'),
#  ('Lewis William', 'Song Yan', 'Tian Yuanhe', 'Xia Fei'),
#  ('Ringger Eric', 'Seppi Kevin', 'Haertel Robbie', 'Felt Paul'),
#  ('Hirst Graeme', 'Brooke Julian'),
#  ('Burchardt Aljoscha',
#   'Krause Sebastian',
#   'Avramidis Eleftherios',
#   "Popovi{\\'c} Maja",
#   'Uszkoreit Hans',
#   'Li Hong',
#   'Xu Feiyu'),
#  ('Zhou Guangyou',
#   'Zhao Jun',
#   'He Shizhu',
#   'Liu Shengping',
#   'Cao Pengfei',
#   'Chen Yubo',
#   'Liu Kang',
#   'Xu Liheng'),
#  ('Quirk Chris', 'Toutanova Kristina', 'Menezes Arul'),
#  ('Kazantseva Anna', 'Szpakowicz Stan'),
#  ('Georgila Kallirroi',
#   'Traum David',
#   'Artstein Ron',
#   'Leuski Anton',
#   'DeVault David'),
#  ("Cuay{\\'a}huitl Heriberto", 'Dethlefs Nina'),
#  ('Sofianopoulos Sokratis', 'Vassiliou Marina'),
#  ('Stevenson Suzanne', 'Fazly Afsaneh'),
#  ('Wu Jian-Cheng', 'Chang Jason S.'),
#  ("Nagy T. Istv{\\'a}n", "Farkas Rich{\\'a}rd", 'Vincze Veronika'),
#  ('Liu Xingkun',
#   'Hastie Helen',
#   'Eshghi Arash',
#   'Du{\\v{s}}ek Ond{\\v{r}}ej',
#   'Janarthanam Srinivasan',
#   'Rieser Verena',
#   'Lemon Oliver'),
#  ('Zarrie{\\ss} Sina', 'Kennington Casey', 'Schlangen David', 'Baumann Timo'),
#  ('Xu Hu', 'Mukherjee Arjun', 'Shu Lei', 'Liu Bing'),
#  ('Wang Yu-Chun',
#   'Hsieh Yu-Lun',
#   'Chang Yung-Chun',
#   'Tsai Richard Tzong-Han',
#   'Hsu Wen-Lian'),
#  ('Visweswariah Karthik', 'Ramanathan Ananthakrishnan'),
#  ('Yu Tao', 'Abu-Jbara Amjad', 'Zhang Rui', 'Radev Dragomir'),
#  ('Blanco Eduardo', 'Moldovan Dan'),
#  ('Erk Katrin', "Pad{\\'o} Sebastian"),
#  ('Nenkova Ani', 'Louis Annie'),
#  ('Rehbein Ines', 'Ruppenhofer Josef', 'Wiegand Michael', 'Klakow Dietrich'),
#  ('McKeown Kathleen', 'Thadani Kapil'),
#  ('Iglesias Gonzalo',
#   'Saunders Danielle',
#   'Byrne Bill',
#   'de Gispert Adri{\\`a}',
#   'Stahlberg Felix',
#   'Byrne William'),
#  ('Swift Mary', 'Galescu Lucian', 'Allen James'),
#  ("Branco Ant{\\'o}nio",
#   'Costa Francisco',
#   "Gomes Lu{\\'\\i}s",
#   'Saedi Chakaveh',
#   'Silva Jo{\\~a}o'),
#  ('Eger Steffen',
#   'Berant Jonathan',
#   'Horbach Andrea',
#   'Stanovsky Gabriel',
#   'Miller Tristan',
#   'Eckart de Castilho Richard',
#   'Shwartz Vered',
#   'Daxenberger Johannes',
#   'Gurevych Iryna',
#   'Lee Kenton',
#   'Artzi Yoav',
#   'Szpektor Idan',
#   'Shnarch Eyal',
#   'Zesch Torsten',
#   'Levy Omer',
#   'Reimers Nils',
#   'Eckle-Kohler Judith',
#   'Zettlemoyer Luke',
#   'Stab Christian',
#   'Zhao Wei',
#   'Habernal Ivan',
#   'Lewis Mike',
#   'Dagan Ido',
#   'Goldberger Jacob',
#   'Meyer Christian M.'),
#  ('Khashabi Daniel',
#   'Mayhew Stephen',
#   'Rozovskaya Alla',
#   'Upadhyay Shyam',
#   'Roth Dan',
#   'Goldwasser Dan',
#   'Peng Haoruo',
#   'Srikumar Vivek',
#   'Sammons Mark',
#   'Ning Qiang'),
#  ('Matsoukas Spyros', 'Makhoul John', 'Schwartz Richard'),
#  ('Soderland Stephen', '{Mausam}', 'Etzioni Oren'),
#  ('Jurafsky Dan', 'Chambers Nathanael'),
#  ('Stymne Sara', 'Ahrenberg Lars'),
#  ('Camacho-Collados Jose',
#   'Navigli Roberto',
#   'Pilehvar Mohammad Taher',
#   'Velardi Paola',
#   'Collier Nigel',
#   'Conia Simone'),
#  ('Elazar Yanai', 'Ravfogel Shauli', 'Elhadad Michael', 'Goldberg Yoav'),
#  ('Yu Hao', 'Meng Yao'),
#  ('Husain Samar', 'Sharma Dipti Misra', 'Sangal Rajeev'),
#  ('Gonzalo Julio', "Amig{\\'o} Enrique", 'Verdejo Felisa'),
#  ('Dymetman Marc', 'Cancedda Nicola'),
#  ('Eisele Andreas', 'Chen Yu'),
#  ('Broeder Daan', 'Wittenburg Peter'),
#  ('Kow Eric', 'Gatt Albert', 'Belz Anja'),
#  ('Krishnaswamy Nikhil',
#   'Verhagen Marc',
#   'Pustejovsky James',
#   'Suderman Keith',
#   'Rogers Anna',
#   'Ide Nancy',
#   'Romanov Alexey',
#   'Rumshisky Anna'),
#  ('Lardilleux Adrien', 'Lepage Yves'),
#  ('White Michael', 'Rajkumar Rajakrishnan'),
#  ('Kashioka Hideki', 'Hori Chiori'),
#  ('Okada Yoshihiro', 'Watanabe Yasuhiko'),
#  ('Kuhlmann Marco', 'Nederhof Mark-Jan', 'Satta Giorgio'),
#  ('Okuno Hiroshi G.', 'Funakoshi Kotaro', 'Komatani Kazunori', 'Nakano Mikio'),
#  ('Balahur Alexandra',
#   "Guti{\\'e}rrez Yoan",
#   "Montoyo Andr{\\'e}s",
#   'Mu{\\~n}oz Rafael'),
#  ('Huang Hen-Hsen',
#   'Chen Hsin-Hsi',
#   'Chen Chung-Chi',
#   'Huang Ting-Hao',
#   'Ku Lun-Wei'),
#  ('Kwong Oi Yee', 'Tsou Benjamin K.'),
#  ('Trost Harald', 'Matiasek Johannes'),
#  ('Lombardo Vincenzo', 'Lesmo Leonardo'),
#  ('Nilsson Jens', 'Hall Johan', 'de Lhoneux Miryam', 'Nivre Joakim'),
#  ('Matsubara Shigeki', 'Kato Yoshihide', 'Inagaki Yasuyoshi', 'Ohno Tomohiro'),
#  ('Johansson Richard', 'Nugues Pierre'),
#  ('Boullier Pierre',
#   'Sagot Beno{\\^\\i}t',
#   "Seddah Djam{\\'e}",
#   'Candito Marie'),
#  ('Dale Robert', 'Viethen Jette', "Paris C{\\'e}cile", 'Wan Stephen'),
#  ('Buechel Sven',
#   'Hahn Udo',
#   'Hellrich Johannes',
#   'Tomanek Katrin',
#   'Wermter Joachim'),
#  ('Casacuberta Francisco',
#   "Ortiz-Mart{\\'\\i}nez Daniel",
#   'Vidal Enrique',
#   "Gonz{\\'a}lez-Rubio Jes{\\'u}s",
#   "Sanchis-Trilles Germ{\\'a}n"),
#  ('Laparra Egoitz',
#   'Labaka Gorka',
#   'Rigau German',
#   'Cuadros Montse',
#   'Caselli Tommaso',
#   'Maks Isa',
#   'Soroa Aitor',
#   'Martinez David',
#   'Fellbaum Christiane',
#   'Sarasola Kepa',
#   'Artetxe Mikel',
#   'Postma Marten',
#   'Vossen Piek',
#   'Agirre Eneko',
#   'Fokkens Antske',
#   'Lopez de Lacalle Oier'),
#  ('Carpuat Marine',
#   'Saers Markus',
#   'Addanki Karteek',
#   'Wu Dekai',
#   'Lo Chi-kiu'),
#  ('Reffin Jeremy', 'Briscoe Ted', 'Weir David', 'Weeds Julie', 'Carroll John'),
#  ('Starlander Marianne',
#   'Hockey Beth Ann',
#   'Bouillon Pierrette',
#   'Chatzichrisafis Nikos',
#   'Rayner Manny',
#   'Nakao Yukie',
#   'Santaholma Marianne',
#   'Tsourakis Nikos',
#   'Gerlach Johanna'),
#  ('Gliozzo Alfio', 'Glass Michael', 'Strapparava Carlo'),
#  ('Ma Xuezhe',
#   'Lin Chin-Yew',
#   'Mitamura Teruko',
#   'Hovy Eduard',
#   'Gangal Varun',
#   'Liu Jing',
#   'Nyberg Eric',
#   'Zhou Liang',
#   'Araki Jun'),
#  ('Castro Ferreira Thiago',
#   'Daelemans Walter',
#   'Wubben Sander',
#   'Krahmer Emiel',
#   'Morante Roser',
#   'Hendrickx Iris',
#   'van der Lee Chris',
#   'van den Bosch Antal'),
#  ('Scott Donia', 'Power Richard', 'Williams Sandra'),
#  ('Fujii Atsushi', 'Ishikawa Tetsuya'),
#  ('Helmreich Stephen', 'Farwell David'),
#  ('Niu Cheng', 'Li Wei'),
#  ('Tokunaga Takenobu', 'Tanaka Hozumi', 'Iida Ryu'),
#  ('Langlais Philippe',
#   'Lapalme Guy',
#   'Patry Alexandre',
#   'Gotti Fabrizio',
#   'Simard Michel'),
#  ('Corston-Oliver Simon', 'Gamon Michael'),
#  ('Bruce Rebecca',
#   'Wiebe Janyce',
#   'Liang Paul Pu',
#   "P{\\'e}rez-Rosas Ver{\\'o}nica",
#   'Somasundaran Swapna',
#   'Wilson Theresa',
#   'Cambria Erik',
#   'Majumder Navonil',
#   'Morency Louis-Philippe',
#   'Poria Soujanya',
#   'Hazarika Devamanyu',
#   'Mihalcea Rada',
#   'Banea Carmen'),
#  ('Kokkinakis George', 'Fakotakis Nikos'),
#  ('McShane Marjorie', 'Raskin Victor', 'Nirenburg Sergei', 'Beale Stephen'),
#  ('Andreas Jacob',
#   'Burkett David',
#   'Pauls Adam',
#   'Haghighi Aria',
#   'DeNero John',
#   'Fried Daniel',
#   'de Marneffe Marie-Catherine',
#   'Durrett Greg',
#   'Manning Christopher D.',
#   'Berg-Kirkpatrick Taylor',
#   'Klein Dan',
#   'Green Spence',
#   'Liang Percy'),
#  ('Araki Kenji', 'Tochinai Koji'),
#  ('Aker Ahmet',
#   'Cunningham Hamish',
#   'Guthrie Louise',
#   'Tablan Valentin',
#   'Maynard Diana',
#   'Wilks Yorick',
#   'Hepple Mark',
#   'Bontcheva Kalina',
#   'Gaizauskas Robert',
#   'Derczynski Leon'),
#  ('Chang Jing-Shin',
#   'Zhou Yu',
#   'Zhang Jiajun',
#   'Su Keh-Yih',
#   'Zong Chengqing',
#   'Lin Yi-Chung'),
#  ('Bear John', 'Hobbs Jerry R.'),
#  ('Dahl Deborah A.', 'Norton Lewis M.'),
#  ('Furuse Osamu', 'Iida Hitoshi'),
#  ('Weischedel Ralph', 'Ramshaw Lance', 'Ayuso Damaris', 'Boisen Sean'),
#  ('Della Pietra Vincent J.',
#   'Mercer Robert L.',
#   'Della Pietra Stephen A.',
#   'Brown Peter F.'),
#  ('Zollmann Andreas',
#   'Ding Chenchen',
#   'Lin Chen',
#   'Mino Hideya',
#   'Fu Ruiji',
#   'Bach Nguyen',
#   "Gim{\\'e}nez Jes{\\'u}s",
#   'Cook Paul',
#   'Morishita Makoto',
#   'Xue Nianwen',
#   'Liu Yijia',
#   'Nasr Alexis',
#   'Jiang Yong',
#   'Duh Kevin',
#   'Kawahara Daisuke',
#   'Herrmann Teresa',
#   'Han Jiawei',
#   'Shou Linjun',
#   'Vogel Stephan',
#   'Jiang Jie',
#   'Johnson Mark',
#   'Hartley Anthony',
#   'Piperidis Stelios',
#   'Ren Xiang',
#   'Shi Shuming',
#   'Hewavitharana Sanjika',
#   'Hermann Karl Moritz',
#   'Weese Jonathan',
#   'Kulkarni Malhar',
#   'Poliak Adam',
#   'Wu Hua',
#   'Mehdad Yashar',
#   'Toral Antonio',
#   'Haque Rejwanul',
#   'Bangalore Srinivas',
#   'Wang Xinyu',
#   'Zhou Ming',
#   'Denkowski Michael',
#   'Dredze Mark',
#   'Toda Tomoki',
#   'Biemann Chris',
#   'Moschitti Alessandro',
#   'Hsieh Yu-Ming',
#   'Jiang Xin',
#   'Oh Jong-Hoon',
#   'Chao Lidia S.',
#   'Sasaki Yutaka',
#   'Li Chi-Ho',
#   'Tamchyna Ale{\\v{s}}',
#   'Beck Daniel',
#   "Ga{\\v{s}}i{\\'c} Milica",
#   'Teng Zhiyang',
#   'Qian Xian',
#   'Ponzetto Simone Paolo',
#   "Guzm{\\'a}n Francisco",
#   "Mapelli Val{\\'e}rie",
#   'Qin Bing',
#   'Hermjakob Ulf',
#   'Strzalkowski Tomek',
#   'Tan Liling',
#   'Schmid Helmut',
#   'Ananiadou Sophia',
#   'Duan Nan',
#   'Lu Di',
#   'Bertagna Francesca',
#   'Gao Yingbo',
#   'Dligach Dmitriy',
#   'Cholakov Kostadin',
#   'Ling Wang',
#   'Polifroni Joseph',
#   'Vaidya Ashwini',
#   'Wang Xiaolin',
#   'Koychev Ivan',
#   'Kordoni Valia',
#   "Fu{\\v{c}}{\\'\\i}kov{\\'a} Eva",
#   'Bouamor Houda',
#   'Li Peifeng',
#   'Sornlertlamvanich Virach',
#   'Sap Maarten',
#   'Parida Shantipriya',
#   'Lambert Patrik',
#   'Du Xinya',
#   'Peter Jan-Thorsten',
#   'Arranz Victoria',
#   'Dernoncourt Franck',
#   'Yokoi Sho',
#   'Schmitt Alexander',
#   'Riedl Martin',
#   'Panchenko Alexander',
#   'Wang Longyue',
#   'Su Jian',
#   'Nagata Masaaki',
#   'Croce Danilo',
#   'Kim Yunsu',
#   'Bird Steven',
#   'Sankaran Baskaran',
#   'Liu Lizhen',
#   'Chen Wenliang',
#   'Patra Braja Gopal',
#   'Cromieres Fabien',
#   'Lin Yankai',
#   'Clark Stephen',
#   'Su Pei-Hao',
#   'Monz Christof',
#   'Chen Ying',
#   'Yao Jianmin',
#   'Rashkin Hannah',
#   "Kazama Jun{'}ichi",
#   'Demner-Fushman Dina',
#   'Ferret Olivier',
#   'Sha Lei',
#   'Isozaki Hideki',
#   'Zhang Hao',
#   'Zhang Yue',
#   'Venturi Giulia',
#   'Elfardy Heba',
#   'Zhu Conghui',
#   'May Jonathan',
#   'Pavlick Ellie',
#   'Charniak Eugene',
#   'Chaudhary Vishrav',
#   'Sakti Sakriani',
#   'Savova Guergana',
#   'Pan Xiaoman',
#   'Verspoor Karin',
#   'Huang Shu-Ling',
#   'Tomeh Nadi',
#   'Schwartz Roy',
#   'Zhang Boliang',
#   'Cocos Anne',
#   'Joty Shafiq',
#   'Yamamoto Hirofumi',
#   'Kobayashi Sosuke',
#   'Matsubayashi Yuichiroh',
#   'Katsumata Satoru',
#   'Fujita Sanae',
#   'Leusch Gregor',
#   'Tu Zhaopeng',
#   'Seneff Stephanie',
#   'White Aaron Steven',
#   'Noji Hiroshi',
#   'Smith Noah A.',
#   'Zhang Yu',
#   'Nguyen Thien Huu',
#   'Okazaki Naoaki',
#   'Bojar Ond{\\v{r}}ej',
#   'Ballesteros Miguel',
#   'Sun Xu',
#   'Chu Chenhui',
#   'Duan Xiangyu',
#   'Pyysalo Sampo',
#   'Xu Jingjing',
#   'Bi Wei',
#   'Nicosia Massimo',
#   'Nishino Masaaki',
#   'Palmer Martha',
#   'Madnani Nitin',
#   'Mi Haitao',
#   'Monachini Monica',
#   'Li Junhui',
#   'Lu Qin',
#   'Francopoulo Gil',
#   'Ouchi Hiroki',
#   'El Kholy Ahmed',
#   'Hsieh Shu-Kai',
#   'Dalvi Fahim',
#   'Maharjan Suraj',
#   'Zalmout Nasser',
#   'Dyer Chris',
#   'Li Shoushan',
#   'Shaikh Samira',
#   'Zhang Min',
#   'Isahara Hitoshi',
#   'Uchimoto Kiyotaka',
#   'Cho Eunah',
#   'Ng Raymond',
#   'Durrani Nadir',
#   'Oda Yusuke',
#   'Post Matt',
#   'Li Mu',
#   'Matsumoto Yuji',
#   'Liu Shujie',
#   'Haji{\\v{c}} Jan',
#   'Rimell Laura',
#   'Li Juanzi',
#   'Mare{\\v{c}}ek David',
#   'Van Durme Benjamin',
#   'Carbonell Jaime',
#   'Akhtar Md Shad',
#   'Trancoso Isabel',
#   'Inoue Naoya',
#   'Bansal Mohit',
#   'Thompson Paul',
#   'Li Wenjie',
#   'Weller Marion',
#   'Santus Enrico',
#   'Nicholson Jeremy',
#   'Neubig Graham',
#   'Redkar Hanumant',
#   'Pivovarova Lidia',
#   'Marcu Daniel',
#   'Crego Josep M.',
#   'Ninomiya Takashi',
#   'Tu Kewei',
#   'Khadivi Shahram',
#   'Wang Houfeng',
#   'Xu Hongzhi',
#   'McCarthy Diana',
#   'Voss Clare',
#   'Bui Trung',
#   'Mohit Behrang',
#   'Tateisi Yuka',
#   'Rijhwani Shruti',
#   'Xu Ke',
#   'Karan Mladen',
#   'Anastasopoulos Antonios',
#   'Ekbal Asif',
#   'Mauser Arne',
#   'Ginter Filip',
#   'Song Wei',
#   'Li Haizhou',
#   'Waibel Alex',
#   'Kim Jin-Dong',
#   'Cohen Kevin Bretonnel',
#   'Bisazza Arianna',
#   'Aufrant Lauriane',
#   'Lu Bao-Liang',
#   'Ma Yanjun',
#   'Xiang Rong',
#   'Imamura Kenji',
#   'Mishra Abhijit',
#   'Kuribayashi Tatsuki',
#   'Paetzold Gustavo',
#   'Dras Mark',
#   'Shindo Hiroyuki',
#   'Nie Yixin',
#   'Lin Ying',
#   'Hashimoto Chikara',
#   'Guo Weiwei',
#   'Williams Philip',
#   'Feng Xiaocheng',
#   'Ma Qing',
#   'Ji Heng',
#   'He Yifan',
#   'He Zhongjun',
#   'Apidianaki Marianna',
#   'Li Manling',
#   'Paul Michael',
#   'Federmann Christian',
#   'Rappoport Ari',
#   'Bosselut Antoine',
#   'Ghoneim Mahmoud',
#   'Das Dipankar',
#   'Escolano Carlos',
#   'Kudo Taku',
#   'Stein Daniel',
#   'Liu Yang',
#   'Logacheva Varvara',
#   'Rahimi Afshin',
#   'Severyn Aliaksei',
#   'Qi Fanchao',
#   'Wang Haifeng',
#   'Ueffing Nicola',
#   'Li Sujian',
#   'Abdelali Ahmed',
#   'Gaido Marco',
#   'Rosa Rudolf',
#   'Torisawa Kentaro',
#   'Niehues Jan',
#   'Frontini Francesca',
#   "{\\v{Z}}abokrtsk{\\'y} Zden{\\v{e}}k",
#   'Liu Lemao',
#   'Wuebker Joern',
#   'Mediani Mohammed',
#   'Livescu Karen',
#   'Basili Roberto',
#   'Huck Matthias',
#   'Liu Zhanyi',
#   'Wang Xing',
#   'Rosset Sophie',
#   'Maegaard Bente',
#   'Yamamoto Seiichi',
#   'Watanabe Taro',
#   'Kim Doo Soon',
#   'Minker Wolfgang',
#   'Darwish Kareem',
#   'Tanaka Takaaki',
#   'Takase Sho',
#   'Hong Yu',
#   'Li Peng',
#   'Costa-juss{\\`a} Marta R.',
#   'Och Franz Josef',
#   'Kamran Amir',
#   'Sennrich Rico',
#   'Fomicheva Marina',
#   "Del{\\'e}ger Louise",
#   'Wu Xiaofeng',
#   'Elsner Micha',
#   'Pighin Daniele',
#   'Al-Badrashiny Mohamed',
#   'Obeid Ossama',
#   'Gupta Deepak',
#   'Inui Kentaro',
#   'Taylor Sarah',
#   'Yimam Seid Muhie',
#   'Kar Sudipta',
#   'Knight Kevin',
#   'Choukri Khalid',
#   'Eck Matthias',
#   'Rojas-Barahona Lina M.',
#   'Abend Omri',
#   'Blunsom Phil',
#   'Zhang Yi',
#   'Feng Yang',
#   'Feng Minwei',
#   'Saha Sriparna',
#   'Galibert Olivier',
#   'Brunato Dominique',
#   'Casanueva I{\\~n}igo',
#   'Tsukada Hajime',
#   'Che Wanxiang',
#   'Lin Shouxun',
#   'Zhang Meishan',
#   'Rapp Reinhard',
#   'Vandyke David',
#   'Huang Lifu',
#   'Finch Andrew',
#   'Chersoni Emmanuele',
#   'Gong Yeyun',
#   'El-Kishky Ahmed',
#   'Ravi Sujith',
#   'Odijk Jan',
#   'Thomson Blaise',
#   'Buck Christian',
#   'Huang Fei',
#   'Huang Shaohan',
#   'Habash Nizar',
#   'Lavie Alon',
#   'Attia Mohammed',
#   'Liu Xiaohua',
#   'Grau Brigitte',
#   'Hawwari Abdelati',
#   'Dabre Raj',
#   'Haddow Barry',
#   'Mohtarami Mitra',
#   'Bertoldi Nicola',
#   'Song Linfeng',
#   'Carenini Giuseppe',
#   'Irvine Ann',
#   'Bonial Claire',
#   'Murawaki Yugo',
#   'Gerz Daniela',
#   'Reichart Roi',
#   'Mistica Meladel',
#   'Bhingardive Sudha',
#   'Jiang Daxin',
#   'Shang Lifeng',
#   'Cui Lei',
#   'Okuma Hideo',
#   'Wang Xinyi',
#   'Zhang Jinchao',
#   'Zhao Tiejun',
#   'Alkhouli Tamer',
#   'van Genabith Josef',
#   'Vilar David',
#   'Pirrelli Vito',
#   'Hill Felix',
#   'Ganitkevitch Juri',
#   'Han Xu',
#   '{\\v{S}}najder Jan',
#   'De Saeger Stijn',
#   'Gui Lin',
#   'Wang Shijin',
#   'Matsuzaki Takuya',
#   'Yao Yuan',
#   'Ponti Edoardo Maria',
#   'Gimpel Kevin',
#   "Rauzy St{\\'e}phane",
#   'Joshi Aditya',
#   'Chen Kehai',
#   'Graham Yvette',
#   'Grishman Ralph',
#   'Meyers Adam',
#   'Illouz Gabriel',
#   'Andrews Nicholas',
#   'Li Chen',
#   'Rudinger Rachel',
#   'Macleod Catherine',
#   'Curran James R.',
#   'Kozareva Zornitsa',
#   'Chang Walter',
#   'Mostefa Djamel',
#   'Suzuki Jun',
#   'Allauzen Alexandre',
#   'Bond Francis',
#   'Hershcovich Daniel',
#   'Belinkov Yonatan',
#   'Cao Yixin',
#   'Sudoh Katsuhito',
#   'Zampolli Antonio',
#   'Cahill Aoife',
#   'Das Dipanjan',
#   'Zhang Dongdong',
#   'Huang Zhongqiang',
#   'Scarton Carolina',
#   'Salehi Bahar',
#   'Sumita Eiichiro',
#   'Sui Zhifang',
#   'Remus Steffen',
#   'Sekine Satoshi',
#   'Khayrallah Huda',
#   'Wei Furu',
#   'Levin Lori',
#   'Da San Martino Giovanni',
#   'Yang Nan',
#   'Egg Markus',
#   'Yvon Fran{\\c{c}}ois',
#   'Way Andy',
#   'Chen Yufeng',
#   'Espa{\\~n}a-Bonet Cristina',
#   'Bai Ming-Hong',
#   'Holtzman Ari',
#   'Gaspari Federico',
#   'Hirasawa Tosho',
#   'Yang Pengcheng',
#   'Bhattacharyya Pushpak',
#   'Xiao Xinyan',
#   'Liu Zhiyuan',
#   'Wisniewski Guillaume',
#   'Montemagni Simonetta',
#   'Lui Marco',
#   'Young Steve',
#   'Zhao Hai',
#   'Sajjad Hassan',
#   "M{\\`a}rquez Llu{\\'\\i}s",
#   'Ding Xiao',
#   'Frederking Robert',
#   'Montes Manuel',
#   'Pouran Ben Veyseh Amir',
#   'Zhang Wei-Nan',
#   'Khalifa Salam',
#   'Xiong Deyi',
#   'Reisert Paul',
#   'Carreras Xavier',
#   'Thomson Sam',
#   'Ren Xuancheng',
#   'Miller Timothy',
#   'Liu Tianyu',
#   'Yangarber Roman',
#   'Wang Tao',
#   'Kaneko Masahiro',
#   'Kocmi Tom',
#   'Asahara Masayuki',
#   'Pasunuru Ramakanth',
#   'Aw Aiti',
#   'Long Yunfei',
#   'Yao Xuchen',
#   'Davidov Dmitry',
#   'Ney Hermann',
#   'Koehn Philipp',
#   'Poncelas Alberto',
#   'Sarkar Anoop',
#   'Zhou Jie',
#   'Kanerva Jenna',
#   'Jiang Wenbin',
#   'Arase Yuki',
#   'Ohta Tomoko',
#   'Callison-Burch Chris',
#   'Xu Jinan',
#   "Fonollosa Jos{\\'e} A. R.",
#   'Kurohashi Sadao',
#   'Hanneman Greg',
#   'Murray Gabriel',
#   'Zens Richard',
#   'Glava{\\v{s}} Goran',
#   'Shibata Tomohide',
#   "Ure{\\v{s}}ov{\\'a} Zde{\\v{n}}ka",
#   'Soria Claudia',
#   'Lenci Alessandro',
#   'Ha Thanh-Le',
#   'Lin Bill Yuchen',
#   'Li Liangyou',
#   'Luan Huanbo',
#   'Lau Jey Han',
#   'Kajiwara Tomoyuki',
#   'Su Jinsong',
#   'Meng Fandong',
#   'Liu Ting',
#   'Su Qi',
#   "Vuli{\\'c} Ivan",
#   'Lauscher Anne',
#   'Peitz Stephan',
#   'Kim Su Nam',
#   'Diab Mona',
#   'Zhang Sheng',
#   'Hashimoto Kazuma',
#   'Phillips Michael',
#   'Tan Chew Lim',
#   'Bhagavatula Chandra',
#   'Prabhakaran Vinodkumar',
#   "Tsujii Jun{'}ichi",
#   'Zhang Ying',
#   'Nakov Preslav',
#   'Chen Keh-Jiann',
#   'Zhang Yujie',
#   'Mansour Saab',
#   'Zhou Guodong',
#   'Pal Santanu',
#   'Zue Victor',
#   'Du Jinhua',
#   'Goto Isao',
#   'Wong Derek F.',
#   'Ustalov Dmitry',
#   'Cohn Trevor',
#   'Wen Tsung-Hsien',
#   'Mizuno Junta',
#   'Banchs Rafael E.',
#   'Sun Maosong',
#   'Solorio Thamar',
#   'Freitag Markus',
#   'Knowles Rebecca',
#   'Li Sheng',
#   'Miyao Yusuke',
#   'Yin Pengcheng',
#   'Vela Mihaela',
#   'Patel Kevin',
#   'Pazienza Maria Teresa',
#   'Bethard Steven',
#   'Li Zhoujun',
#   'Wieting John',
#   'Pakray Partha',
#   'Mariani Joseph',
#   'Tannier Xavier',
#   'Chang Shih-Fu',
#   'Samih Younes',
#   'Titov Ivan',
#   'Choi Yejin',
#   'Xu Ruifeng',
#   'Hamon Olivier',
#   'Baldwin Timothy',
#   'Chang Baobao',
#   'Ultes Stefan',
#   'Kiela Douwe',
#   'Sterling John',
#   'Aziz Wilker',
#   'Hou Lei',
#   'Bandyopadhyay Sivaji',
#   'Yang Jie',
#   'Tamura Akihiro',
#   'Malmasi Shervin',
#   'Shimbo Masashi',
#   'Gates Donna',
#   'Kanzaki Kyoko',
#   'Popel Martin',
#   'Gildea Daniel',
#   'Qian Longhua',
#   'Faruqui Manaal',
#   'Zweigenbaum Pierre',
#   'Dang Hoa Trang',
#   'Yang Xiaofeng',
#   'Hu Guoping',
#   'Zhang Biao',
#   'Tsvetkov Yulia',
#   'Zhang Zhuosheng',
#   "Moriceau V{\\'e}ronique",
#   'Matusov Evgeny',
#   'Haffari Gholamreza',
#   'Li Zhenghua',
#   'Schneider Nathan',
#   'Bouamor Dhouha',
#   'Nakazawa Toshiaki',
#   'Dorr Bonnie',
#   'Zhang Longkai',
#   'Hasan Sa{\\v{s}}a',
#   'Chen Zheng',
#   'Eskander Ramy',
#   'Birch Alexandra',
#   'Luo Fuli',
#   'Cui Yiming',
#   'Wang Rui',
#   'Budzianowski Pawe{\\l}',
#   'Vilnat Anne',
#   'Yang Min',
#   'Specia Lucia',
#   'Li Zuchao',
#   'Yamamoto Eiko',
#   'Hayashi Katsuhiko',
#   'Calzolari Nicoletta',
#   'Kunchukuttan Anoop',
#   'Venugopal Ashish',
#   'Babych Bogdan',
#   'Yang Muyun',
#   'Miwa Makoto',
#   'Cardie Claire',
#   'McNaught John',
#   'Lavergne Thomas',
#   'Kumaran A',
#   'Ge Tao',
#   'Le Bras Ronan',
#   "Blain Fr{\\'e}d{\\'e}ric",
#   'Dong Li',
#   'Brown Susan Windisch',
#   'Liu Xiaojiang',
#   "N{\\'e}v{\\'e}ol Aur{\\'e}lie",
#   'Gao Wei',
#   'Turchi Marco',
#   'Nothman Joel',
#   'Neves Mariana',
#   'Khalilov Maxim',
#   'Han Wenjuan',
#   'Besan{\\c{c}}on Romaric',
#   'Rambow Owen',
#   'Kong Fang',
#   "Dell{'}Orletta Felice",
#   'Lin Junyang',
#   'Wong Kam-Fai',
#   'Alva-Manchego Fernando',
#   'Shimohata Mitsuo',
#   'Ligozat Anne-Laure',
#   'Sharoff Serge',
#   'Kanojia Diptesh',
#   'Bentivogli Luisa',
#   'Tsuruoka Yoshimasa',
#   'Negri Matteo',
#   'Korhonen Anna',
#   'Fraser Alexander',
#   'Zaghouani Wajdi',
#   'Komachi Mamoru',
#   'Sun Lin',
#   'Hirao Tsutomu',
#   'Poibeau Thierry',
#   'Kloetzer Julien',
#   'Goldwater Sharon',
#   'Zampieri Marcos',
#   'Cettolo Mauro',
#   'Bender Oliver',
#   "Mrk{\\v{s}}i{\\'c} Nikola",
#   'Aguilar Gustavo',
#   'Hu Junjie',
#   'Zeman Daniel',
#   'Swayamdipta Swabha',
#   'Zhao Shiqi',
#   'Hangya Viktor',
#   'Mubarak Hamdy',
#   'Nakamura Satoshi',
#   'Hoang Hieu',
#   'Ma Shuming',
#   'Paroubek Patrick',
#   'Tang Duyu',
#   'Georgiev Georgi',
#   'Wang Weiyue',
#   'Federico Marcello',
#   'Shah Kashif',
#   "Barr{\\'o}n-Cede{\\~n}o Alberto",
#   'Huang Chu-Ren',
#   'Murata Masaki',
#   'Ahrens Kathleen',
#   'Salakoski Tapio',
#   'Stojanovski Dario',
#   'Utiyama Masao',
#   'Zhou GuoDong',
#   'Moens Marie-Francine',
#   'Oflazer Kemal',
#   'Yoshino Koichiro',
#   'Chatterjee Rajen',
#   'Gao Qin',
#   "Mari{\\~n}o Jos{\\'e} B.",
#   'Das Amitava',
#   'Glass James',
#   "Max Aur{\\'e}lien",
#   'Robba Isabelle',
#   'Grouin Cyril',
#   'Liu Qun',
#   'Charoenporn Thatsanee',
#   'Zhu Qiaoming',
#   'Gong Ming',
#   'Naskar Sudip Kumar',
#   'Blache Philippe'),
#  ('Tetreault Joel',
#   'Napoles Courtney',
#   'Leacock Claudia',
#   'Burstein Jill',
#   'Chodorow Martin'),
#  ('Lee Lung-Hao',
#   'Tseng Yuen-Hsien',
#   'Yu Liang-Chih',
#   'Wu Chung-Hsien',
#   'Chen Kuang-hua')]

# %%
len(clusters)
# Out:
# 300

# %%
two_member = []
for x in clusters:
    if len(x) == 2:
        two_member.append(x)
        
len(two_member)
# Out:
# 167

# %% [markdown]
# Interpretation:
#
# Results from the PCY for k = 2, N = 10 were used.
#
# There are in total 300 clusters.
#
# 167 of them have only 2 members. Those authors only collaborated with each other above the threshold that was used.
#
# The rest has more than 2 members which shows that there are some group of authors who tend to collabarate with each other.
